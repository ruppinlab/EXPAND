# %%
#### ------------------------------------------------------------------------------------------
#### author: Ranjan Barman, date: Mar 2, 2025 (modified for immune only)
#### Mapped HoverNet 12 immune-only NPIFs to TCGA_BRCA subtype status (HER2, PR, ER)
#### ------------------------------------------------------------------------------------------

import os
import pandas as pd

# Set working directory
_wpath_ = "/data/Lab_ruppin/Ranjan/HnE/"
os.chdir(_wpath_)
print(f"Working directory: {_wpath_}\n")

# Dataset and input paths
dataset_name = "TCGA_BRCA_FFPE"

# File paths
immune_npifs_file = f"{dataset_name}/outputs/HoverNet/HoverNet_NPIFs_TCGA_BRCA_1106_Filter_Top_25Q_ImmuneOnly.csv"
tcga_subtypes_file = "PA_HIF_BRCA/outputs_clinical/TCGA_BRCA_Subtypes_clinical.tsv"

# Load immune-only NPIFs
immune_npifs_df = pd.read_csv(immune_npifs_file)

# Ensure Slide_Name is in consistent format
immune_npifs_df["Slide_Name"] = immune_npifs_df["Slide_Name"].str[:12]
immune_npifs_df = immune_npifs_df.drop_duplicates(subset=["Slide_Name"], keep="first")

# Load subtype data
tcga_subtypes_data = pd.read_table(tcga_subtypes_file, sep="\t")

# Keep and rename subtype columns
tcga_subtypes_data = tcga_subtypes_data[["sampleID", "HER2_Final_Status_nature2012", "PR_Status_nature2012", "ER_Status_nature2012"]]
tcga_subtypes_data = tcga_subtypes_data.rename(columns={
    "HER2_Final_Status_nature2012": "HER2_Status",
    "PR_Status_nature2012": "PR_Status",
    "ER_Status_nature2012": "ER_Status"
})

# Standardize sample ID by removing '-01' suffix
tcga_subtypes_data["sampleID"] = tcga_subtypes_data["sampleID"].str.replace("-01", "", regex=False)
# Out:
# Working directory: /data/Lab_ruppin/Ranjan/HnE/

# %%
# Merge on sample ID and Slide_Name
merged_df = pd.merge(tcga_subtypes_data, immune_npifs_df, left_on="sampleID", right_on="Slide_Name", how="inner")
merged_df.drop(columns=["Slide_Name"], inplace=True)

# Output path and file name
output_path = f"{dataset_name}/outputs/HoverNet/Subtypes/"
os.makedirs(output_path, exist_ok=True)
output_file = os.path.join(output_path, "HoverNet_ImmuneOnly_NPIFs_Mapped_BRCA_Status_Top25P_Tiles.csv")

# Save merged data
merged_df.to_csv(output_file, index=False)

print(f"Mapped immune-only NPIFs data saved to: {output_file}")
print("Done!")

# Return merged DataFrame if running interactively
merged_df
# Out:
# Mapped immune-only NPIFs data saved to: TCGA_BRCA_FFPE/outputs/HoverNet/Subtypes/HoverNet_ImmuneOnly_NPIFs_Mapped_BRCA_Status_Top25P_Tiles.csv
# Done!
#          sampleID HER2_Status PR_Status ER_Status  Total_Tiles  \
# 0    TCGA-A1-A0SB    Negative  Negative  Positive         1179
# 1    TCGA-A1-A0SD    Negative  Positive  Positive         1003
# 2    TCGA-A1-A0SE    Negative  Positive  Positive         4098
# 3    TCGA-A1-A0SF    Negative  Positive  Positive         1752
# 4    TCGA-A1-A0SH    Negative  Positive  Negative         1618
# ..            ...         ...       ...       ...          ...
# 710  TCGA-EW-A1PB    Negative  Negative  Negative         3389
# 711  TCGA-EW-A1PD    Positive  Positive  Positive         2034
# 712  TCGA-EW-A1PE    Negative  Positive  Positive         2662
# 713  TCGA-EW-A1PF    Negative  Positive  Positive         1331
# 714  TCGA-EW-A1PG    Negative  Positive  Positive         2192
#
#      Filtered_Tiles  Mean Area  Mean Major Axis  Mean Minor Axis  \
# 0               329   6.025637         3.434522         2.396370
# 1               264   5.773401         3.285018         2.407675
# 2              1053   6.915839         3.528585         2.608073
# 3               457   4.510537         2.918297         2.142227
# 4               473   6.190965         3.382322         2.485305
# ..              ...        ...              ...              ...
# 710             939   5.482632         3.139946         2.378415
# 711             568   5.766904         3.212860         2.444914
# 712             753   5.118412         3.095301         2.275220
# 713             340   5.226732         3.087368         2.333896
# 714             564   6.302255         3.381273         2.489754
#
#      Mean Perimeter  Mean Eccentricity  Mean Circularity  Std Area  \
# 0          9.690980           0.672433          0.787732  2.533152
# 1          9.370934           0.636962          0.812644  1.887750
# 2         10.090879           0.633787          0.818044  3.208622
# 3          8.268236           0.635349          0.820480  1.341168
# 4          9.666073           0.631440          0.816383  2.318742
# ..              ...                ...               ...       ...
# 710        9.069134           0.602785          0.821542  1.994682
# 711        9.314245           0.604742          0.822665  1.828997
# 712        8.814928           0.632678          0.811471  1.770513
# 713        8.926776           0.602812          0.817199  1.625512
# 714        9.657456           0.633521          0.816395  2.917681
#
#      Std Major Axis  Std Minor Axis  Std Perimeter  Std Eccentricity  \
# 0          0.820652        0.491219       2.202946          0.144434
# 1          0.648373        0.388339       1.654835          0.146252
# 2          0.848080        0.600537       2.346727          0.144584
# 3          0.538948        0.309527       1.348932          0.148232
# 4          0.737734        0.424438       1.889158          0.149531
# ..              ...             ...            ...               ...
# 710        0.658274        0.393364       1.706653          0.155256
# 711        0.612447        0.366758       1.568889          0.147191
# 712        0.619668        0.387539       1.592570          0.151494
# 713        0.638581        0.327071       1.603382          0.152839
# 714        0.819829        0.548441       2.215139          0.146904
#
#      Std Circularity
# 0           0.081289
# 1           0.062008
# 2           0.061430
# 3           0.064460
# 4           0.065511
# ..               ...
# 710         0.063612
# 711         0.059226
# 712         0.063336
# 713         0.073113
# 714         0.061263
#
# [715 rows x 18 columns]
