# %%
#### ------------------------------------------------------------------------------------------
#### author: Ranjan Barman, date: June 22, 2025
#### Mapped POST_NAT HoverNet NPIFs to BRCA subtypes status (using top 25  tiles)
#### Includes patient ID trace and unmatched checks (cleaned version)
#### ------------------------------------------------------------------------------------------

import os
import pandas as pd

# Set working directory
_wpath_ = "/data/Lab_ruppin/Ranjan/HnE/"
os.chdir(_wpath_)
print(f"Working directory: {_wpath_}\n")

# Dataset name
dataset_name = "POST_NAT_BRCA"

# File paths
npif_file = f"{dataset_name}/HoverNet/outputs/POST_NAT_BRCA_HoverNet_NPIFs_Filtered_Tiles_Top25Q.csv"
slide_list_file = "/data/Ruppin_AI/Datasets/Post_NAT_BRCA/processed/Post_NAT_BRCA_slide_list.tsv"
clinical_metadata_file = "/data/Ruppin_AI/Datasets/Post_NAT_BRCA/processed/Post_NAT_BRCA_clinical_metadata_short.tsv"

# Load NPIFs and extract Slide_ID
npif_df = pd.read_csv(npif_file)
npif_df["Slide_ID"] = npif_df["Slide_ID"].astype(int)

# Load slide-to-patient mapping and clinical metadata
slide_list_df = pd.read_csv(slide_list_file, sep="\t")
clinical_metadata_df = pd.read_csv(clinical_metadata_file, sep="\t")
slide_list_df
clinical_metadata_df
# Out:
# Working directory: /data/Lab_ruppin/Ranjan/HnE/
#    Patient_ID  Age Menopausal_status  Lymphovascular_invasion Histology_type  \
# 0          P1   67              Post                      1.0            IDC
# 1          P2   30               Pre                      1.0            IDC
# 2          P3   65              Post                      1.0            IDC
# 3          P4   41               Pre                      0.0            IDC
# 4          P5   47               Pre                      0.0            IDC
# 5          P6   58              Post                      1.0            ILC
# 6          P7   39               Pre                      0.0            IDC
# 7          P8   52               Pre                      0.0            IDC
# 8          P9   34               Pre                      0.0            IDC
# 9         P10   55              Post                      1.0            IDC
# 10        P11   41               Pre                      0.0            IDC
# 11        P12   34               Pre                      0.0            IDC
# 12        P13   80              Post                      0.0         MC/IDC
# 13        P14   72              Post                      0.0            IDC
# 14        P15   33               Pre                      0.0            IDC
# 15        P16   45              Post                      0.0            IDC
# 16        P17   50               Pre                      NaN            IDC
# 17        P18   32               Pre                      0.0            IDC
# 18        P19   44               Pre                      1.0            IMC
# 19        P20   58               NaN                      0.0            IDC
# 20        P21   54              Post                      1.0            IDC
# 21        P22   59              Post                      1.0            IDC
# 22        P23   48               Pre                      0.0            IDC
# 23        P24   43               Pre                      0.0            IDC
# 24        P25   57              Post                      0.0            ITC
# 25        P26   50               Pre                      0.0            IDC
# 26        P27   50              Post                      1.0            IDC
# 27        P28   47               NaN                      0.0            IDC
# 28        P29   63              Post                      0.0            IDC
# 29        P30   83              Post                      0.0         ILC(P)
# 30        P31   49               NaN                      0.0            IDC
# 31        P32   64              Post                      0.0            IDC
# 32        P33   70              Post                      0.0            IDC
# 33        P34   48               Pre                      0.0       ILC(P&C)
# 34        P35   47               Pre                      0.0        ILC (P)
# 35        P36   37               Pre                      0.0            IDC
# 36        P37   53               NaN                      0.0            IDC
# 37        P38   47              Peri                      NaN            IDC
# 38        P39   47               Pre                      0.0            IDC
# 39        P40   69              Peri                      0.0            IDC
# 40        P41   39               Pre                      0.0            IDC
# 41        P42   47              Peri                      NaN            IDC
# 42        P43   49               NaN                      0.0            IDC
# 43        P44   38               Pre                      1.0            IDC
# 44        P45   48               Pre                      1.0            IDC
# 45        P46   68              Post                      0.0            IDC
# 46        P47   61              Post                      1.0            IDC
# 47        P48   60              Post                      1.0            IDC
# 48        P49   37               Pre                      1.0            IDC
# 49        P50   39               Pre                      0.0            IDC
# 50        P51   68              Post                      0.0       ILC ( C)
# 51        P52   36               Pre                      0.0            IDC
# 52        P53   70              Post                      1.0            IDC
# 53        P54   45               Pre                      0.0            IDC
#
#    Histology_grade  HER2_status  ER_status  PR_status Clinical_subtype  \
# 0                3          0.0        1.0        1.0              HR+
# 1                3          1.0        0.0        0.0            HER2+
# 2                2          0.0        1.0        1.0              HR+
# 3                2          0.0        1.0        1.0              HR+
# 4     Undetermined          1.0        1.0        1.0            HER2+
# 5                2          0.0        1.0        1.0              HR+
# 6                3          0.0        0.0        0.0             TNBC
# 7                2          0.0        1.0        1.0              HR+
# 8                2          1.0        1.0        0.0            HER2+
# 9                2          0.0        1.0        1.0              HR+
# 10               2          0.0        0.0        0.0             TNBC
# 11    Undetermined          0.0        0.0        0.0             TNBC
# 12               3          0.0        0.0        0.0             TNBC
# 13               2          0.0        1.0        1.0              HR+
# 14               2          0.0        1.0        1.0              HR+
# 15               2          0.0        1.0        1.0              HR+
# 16               2          0.0        1.0        1.0              HR+
# 17               3          0.0        0.0        0.0             TNBC
# 18               1          0.0        1.0        0.0              HR+
# 19               2          1.0        1.0        1.0            HER2+
# 20               2          0.0        1.0        1.0              HR+
# 21               2          0.0        0.0        0.0             TNBC
# 22               2          1.0        1.0        1.0            HER2+
# 23               3          0.0        0.0        0.0             TNBC
# 24               1          0.0        1.0        1.0              HR+
# 25               2          0.0        1.0        1.0              HR+
# 26               3          0.0        0.0        0.0             TNBC
# 27               3          1.0        0.0        0.0            HER2+
# 28               1          0.0        1.0        0.0              HR+
# 29               2          1.0        1.0        1.0            HER2+
# 30               3          1.0        1.0        1.0            HER2+
# 31               2          0.0        1.0        1.0              HR+
# 32               2          1.0        1.0        1.0            HER2+
# 33               2          0.0        1.0        1.0              HR+
# 34               2          0.0        1.0        1.0              HR+
# 35               2          0.0        1.0        1.0              HR+
# 36               2          0.0        0.0        0.0             TNBC
# 37               2          0.0        1.0        1.0              HR+
# 38               3          NaN        NaN        NaN              NaN
# 39               1          0.0        1.0        1.0              HR+
# 40               2          1.0        1.0        0.0            HER2+
# 41               2          0.0        1.0        1.0              HR+
# 42               3          0.0        0.0        0.0             TNBC
# 43               3          0.0        1.0        1.0              HR+
# 44               1          0.0        1.0        0.0              HR+
# 45               2          0.0        1.0        1.0              HR+
# 46               2          0.0        0.0        0.0             TNBC
# 47               3          0.0        0.0        0.0             TNBC
# 48               2          0.0        1.0        1.0              HR+
# 49               3          0.0        1.0        NaN              HR+
# 50               2          0.0        1.0        1.0              HR+
# 51               3          NaN        NaN        NaN              NaN
# 52               1          0.0        1.0        1.0              HR+
# 53               1          NaN        NaN        NaN              NaN
#
#    Clinical_subtype_fine                NAT_regimen  \
# 0                    HR+            Chemo+Endocrine
# 1                  HER2+            Chemo+Anti-HER2
# 2                    HR+                      Chemo
# 3                    HR+                      Chemo
# 4                   TPBC            Chemo+Anti-HER2
# 5                    HR+                      Chemo
# 6                   TNBC                      Chemo
# 7                    HR+                      Chemo
# 8                   TPBC            Chemo+Anti-HER2
# 9                    HR+                      Chemo
# 10                  TNBC                      Chemo
# 11                  TNBC                      Chemo
# 12                  TNBC            Chemo+Radiation
# 13                   HR+                      Chemo
# 14                   HR+                      Chemo
# 15                   HR+                      Chemo
# 16                   HR+                      Chemo
# 17                  TNBC                      Chemo
# 18                   HR+                      Chemo
# 19                  TPBC                        NaN
# 20                   HR+                      Chemo
# 21                  TNBC                  Radiation
# 22                  TPBC            Chemo+Anti-HER2
# 23                  TNBC                      Chemo
# 24                   HR+                      Chemo
# 25                   HR+                      Chemo
# 26                  TNBC                      Chemo
# 27                 HER2+            Chemo+Anti-HER2
# 28                   HR+                  Endocrine
# 29                  TPBC  Chemo+Anti-HER2+Endocrine
# 30                  TPBC                  Radiation
# 31                   HR+                      Chemo
# 32                  TPBC                  Endocrine
# 33                   HR+                      Chemo
# 34                   HR+                      Chemo
# 35                   HR+                      Chemo
# 36                  TNBC                      Chemo
# 37                   HR+                      Chemo
# 38                   NaN                      Chemo
# 39                   HR+                      Chemo
# 40                  TPBC                      Chemo
# 41                   HR+                      Chemo
# 42                  TNBC                      Chemo
# 43                   HR+                      Chemo
# 44                   HR+                      Chemo
# 45                   HR+                      Chemo
# 46                  TNBC                      Chemo
# 47                  TNBC                      Chemo
# 48                   HR+                      Chemo
# 49                   HR+                      Chemo
# 50                   HR+                  Endocrine
# 51                   NaN            Chemo+Anti-HER2
# 52                   HR+                      Chemo
# 53                   NaN            Chemo+Anti-HER2
#
#                                   Surgery_type_breast  \
# 0                                    Total mastectomy
# 1                                    Total mastectomy
# 2                       Partial mastectomy/lumpectomy
# 3                                    Total mastectomy
# 4                                    Total mastectomy
# 5                                    Total mastectomy
# 6                                    Total mastectomy
# 7                                    Total mastectomy
# 8                                    Total mastectomy
# 9                                    Total mastectomy
# 10                                   Total mastectomy
# 11                                   Total mastectomy
# 12                                   Total mastectomy
# 13                      Partial mastectomy/lumpectomy
# 14                                   Total mastectomy
# 15                                   Total mastectomy
# 16                                   Total mastectomy
# 17                                   Total mastectomy
# 18                                   Total mastectomy
# 19                                   Total mastectomy
# 20                                   Total mastectomy
# 21                                   Total mastectomy
# 22                                   Total mastectomy
# 23                      Partial mastectomy/lumpectomy
# 24                      Partial mastectomy/lumpectomy
# 25                                   Total mastectomy
# 26                                   Total mastectomy
# 27                                   Total mastectomy
# 28                      Partial mastectomy/lumpectomy
# 29                                   Total mastectomy
# 30                      Partial mastectomy/lumpectomy
# 31                      Partial mastectomy/lumpectomy
# 32                      Partial mastectomy/lumpectomy
# 33                                   Total mastectomy
# 34                                   Total mastectomy
# 35                                   Total mastectomy
# 36                      Partial mastectomy/lumpectomy
# 37                                   Total mastectomy
# 38  Partial mastectomy/lumpectomy with 1+ margin r...
# 39                                                4.0
# 40                                   Total mastectomy
# 41                                   Total mastectomy
# 42                                   Total mastectomy
# 43                                   Total mastectomy
# 44                                   Total mastectomy
# 45                                   Total mastectomy
# 46                                   Total mastectomy
# 47  Partial mastectomy/lumpectomy with 1+ margin r...
# 48  Partial mastectomy/lumpectomy with 1+ margin r...
# 49                      Partial mastectomy/lumpectomy
# 50  Partial mastectomy/lumpectomy with 1+ margin r...
# 51                                   Total mastectomy
# 52                                   Total mastectomy
# 53                                   Total mastectomy
#
#                                 Surgery_type_LN Response
# 0                        Axillary LN dissection      PDR
# 1                        Axillary LN dissection      PDR
# 2                        Axillary LN dissection      PDR
# 3                            Sentinel LN biopsy      NDR
# 4                        Axillary LN dissection      PDR
# 5                        Axillary LN dissection      PDR
# 6                            Sentinel LN biopsy      PDR
# 7                        Axillary LN dissection      PDR
# 8                        Axillary LN dissection      PDR
# 9                        Axillary LN dissection      PDR
# 10                           Sentinel LN biopsy      PDR
# 11                       Axillary LN dissection      PDR
# 12                       Axillary LN dissection      PDR
# 13                                          NaN      PDR
# 14                       Axillary LN dissection      PDR
# 15                       Axillary LN dissection      PDR
# 16                           Sentinel LN biopsy      PDR
# 17                       Axillary LN dissection      PDR
# 18                       Axillary LN dissection      PDR
# 19                           Sentinel LN biopsy      PDR
# 20                       Axillary LN dissection      PDR
# 21  Sentinel LN biopsy + Axillary LN dissection      PDR
# 22                       Axillary LN dissection      PDR
# 23                       Axillary LN dissection      PDR
# 24                           Sentinel LN biopsy      NaN
# 25                       Axillary LN dissection      PDR
# 26                                          NaN      MPR
# 27                       Axillary LN dissection      PDR
# 28                                          NaN      NDR
# 29                       Axillary LN dissection      PDR
# 30                           Sentinel LN biopsy      PDR
# 31                           Sentinel LN biopsy      PDR
# 32                           Sentinel LN biopsy      PDR
# 33                           Sentinel LN biopsy      PDR
# 34                       Axillary LN dissection      PDR
# 35                           Sentinel LN biopsy      PDR
# 36                           Sentinel LN biopsy      PDR
# 37                       Axillary LN dissection      PDR
# 38                           Sentinel LN biopsy      PDR
# 39                           Sentinel LN biopsy      PDR
# 40                           Sentinel LN biopsy      PDR
# 41                       Axillary LN dissection      PDR
# 42  Sentinel LN biopsy + Axillary LN dissection      PDR
# 43                       Axillary LN dissection      PDR
# 44                           Sentinel LN biopsy      PDR
# 45  Sentinel LN biopsy + Axillary LN dissection      PDR
# 46                       Axillary LN dissection      PDR
# 47                       Axillary LN dissection      PDR
# 48                       Axillary LN dissection      PDR
# 49                       Axillary LN dissection      PDR
# 50                           Sentinel LN biopsy      PDR
# 51                       Axillary LN dissection      PDR
# 52                       Axillary LN dissection      PDR
# 53                       Axillary LN dissection      PDR

# %%
# Merge Slide_ID to get Patient_ID
npif_mapped_df = pd.merge(npif_df, slide_list_df[["Patient_ID", "Slide_ID"]], on="Slide_ID", how="left")
npif_mapped_df = npif_mapped_df.dropna(subset=["Patient_ID"])
npif_mapped_df["Patient_ID"] = npif_mapped_df["Patient_ID"].astype(str)

# Drop any pre-existing clinical columns to avoid duplication
columns_to_drop = ["HER2_Status", "ER_Status", "PR_Status", "Clinical_subtype"]
npif_mapped_df = npif_mapped_df.drop(columns=[col for col in columns_to_drop if col in npif_mapped_df.columns])

# Prepare and rename clinical subtype columns
clinical_metadata_df["Patient_ID"] = clinical_metadata_df["Patient_ID"].astype(str)
subtypes_df = clinical_metadata_df.rename(columns={
    "HER2_status": "HER2_Status",
    "ER_status": "ER_Status",
    "PR_status": "PR_Status"
})[["Patient_ID", "HER2_Status", "ER_Status", "PR_Status", "Clinical_subtype"]]

# Map binary values to 'Positive'/'Negative'
binary_map = {1.0: "Positive", 0.0: "Negative"}
subtypes_df["HER2_Status"] = subtypes_df["HER2_Status"].map(binary_map)
subtypes_df["ER_Status"] = subtypes_df["ER_Status"].map(binary_map)
subtypes_df["PR_Status"] = subtypes_df["PR_Status"].map(binary_map)

# Merge subtype info into npif_mapped_df
merged_df = pd.merge(subtypes_df, npif_mapped_df, on="Patient_ID", how="inner")

# Reorder to make Patient_ID the first column
cols = merged_df.columns.tolist()
cols.insert(0, cols.pop(cols.index("Patient_ID")))
merged_df = merged_df[cols]

# Print unique Slide_Name and Patient_ID values
print("Patient_IDs from POST_NAT_BRCA_HoverNet_NPIFs (Total: {}):".format(len(merged_df)))
print(merged_df["Patient_ID"].unique())

print("\nPatient IDs from POST_NAT clinical metadata (Total: {}):".format(len(subtypes_df)))
print(subtypes_df["Patient_ID"].unique())

# Find non-matching values
slide_ids = set(merged_df["Patient_ID"])
patient_ids = set(subtypes_df["Patient_ID"])

non_matching_slides = slide_ids - patient_ids
non_matching_patients = patient_ids - slide_ids

print("\nHoverNet NPIFs that do NOT have a matching Patient_ID:")
print(non_matching_slides)

print("\nClinical metadata entries that do NOT have a matching Slide NPIF:")
print(non_matching_patients)
# Out:
# Patient_IDs from POST_NAT_BRCA_HoverNet_NPIFs (Total: 93):
# ['P1' 'P2' 'P3' 'P4' 'P5' 'P6' 'P7' 'P8' 'P9' 'P10' 'P11' 'P12' 'P13'
#  'P14' 'P15' 'P16' 'P17' 'P18' 'P19' 'P20' 'P21' 'P22' 'P23' 'P24' 'P25'
#  'P26' 'P27' 'P28' 'P29' 'P30' 'P31' 'P32' 'P33' 'P34' 'P35' 'P37' 'P38'
#  'P39' 'P40' 'P41' 'P42' 'P43' 'P44' 'P45' 'P46' 'P47' 'P48' 'P49' 'P50'
#  'P51' 'P52' 'P53' 'P54']
#
# Patient IDs from POST_NAT clinical metadata (Total: 54):
# ['P1' 'P2' 'P3' 'P4' 'P5' 'P6' 'P7' 'P8' 'P9' 'P10' 'P11' 'P12' 'P13'
#  'P14' 'P15' 'P16' 'P17' 'P18' 'P19' 'P20' 'P21' 'P22' 'P23' 'P24' 'P25'
#  'P26' 'P27' 'P28' 'P29' 'P30' 'P31' 'P32' 'P33' 'P34' 'P35' 'P36' 'P37'
#  'P38' 'P39' 'P40' 'P41' 'P42' 'P43' 'P44' 'P45' 'P46' 'P47' 'P48' 'P49'
#  'P50' 'P51' 'P52' 'P53' 'P54']
#
# HoverNet NPIFs that do NOT have a matching Patient_ID:
# set()
#
# Clinical metadata entries that do NOT have a matching Slide NPIF:
# {'P36'}

# %%
# Save merged (slide-level) result
output_dir = f"{dataset_name}/outputs/HoverNet/Subtypes/"
os.makedirs(output_dir, exist_ok=True)
output_file = os.path.join(output_dir, "HoverNet_Original_NPIFs_Values_POST_NAT_BRCA_Mapped_BRCA_Status_Filtered_Tiles_Top25Q.csv")
# --------------------------------------
# Patient-level aggregation of NPIFs
# --------------------------------------

# Identify NPIF feature columns to average
mean_std_cols = [col for col in merged_df.columns if col.startswith("Mean ") or col.startswith("Std ")]

# Aggregate NPIFs by Patient_ID (mean), keep first for clinical/status columns
patient_level_df = merged_df.groupby("Patient_ID").agg({
    "HER2_Status": "first",
    "ER_Status": "first",
    "PR_Status": "first",
    "Clinical_subtype": "first",
    **{col: "mean" for col in mean_std_cols}
}).reset_index()

# Save patient-level aggregated results to the same file (overwrite)
patient_level_df.to_csv(output_file, index=False)
print(f"\nPatient-level averaged data saved to: {output_file}")
patient_level_df
# Out:
# Patient-level averaged data saved to: POST_NAT_BRCA/outputs/HoverNet/Subtypes/HoverNet_Original_NPIFs_Values_POST_NAT_BRCA_Mapped_BRCA_Status_Filtered_Tiles_Top25Q.csv
#    Patient_ID HER2_Status ER_Status PR_Status Clinical_subtype  Mean Area  \
# 0          P1    Negative  Positive  Positive              HR+  10.352435
# 1         P10    Negative  Positive  Positive              HR+   9.244911
# 2         P11    Negative  Negative  Negative             TNBC  10.982113
# 3         P12    Negative  Negative  Negative             TNBC   9.004845
# 4         P13    Negative  Negative  Negative             TNBC  14.567301
# 5         P14    Negative  Positive  Positive              HR+  14.540743
# 6         P15    Negative  Positive  Positive              HR+   9.454632
# 7         P16    Negative  Positive  Positive              HR+  11.799307
# 8         P17    Negative  Positive  Positive              HR+  11.725796
# 9         P18    Negative  Negative  Negative             TNBC   9.531761
# 10        P19    Negative  Positive  Negative              HR+   9.874259
# 11         P2    Positive  Negative  Negative            HER2+  12.333581
# 12        P20    Positive  Positive  Positive            HER2+  12.587680
# 13        P21    Negative  Positive  Positive              HR+   9.140832
# 14        P22    Negative  Negative  Negative             TNBC  15.653020
# 15        P23    Positive  Positive  Positive            HER2+   9.375505
# 16        P24    Negative  Negative  Negative             TNBC   9.223671
# 17        P25    Negative  Positive  Positive              HR+   9.574072
# 18        P26    Negative  Positive  Positive              HR+  10.324420
# 19        P27    Negative  Negative  Negative             TNBC  11.390214
# 20        P28    Positive  Negative  Negative            HER2+  11.200520
# 21        P29    Negative  Positive  Negative              HR+  10.970780
# 33          0.760934   6.101871        1.381562        0.856053
# 34          0.780069   6.726942        1.236035        0.978307
# 35          0.762093   4.538598        1.128082        0.691929
# 36          0.738626   7.169019        1.534395        0.972440
# 37          0.756467   6.617130        1.378751        0.933387
# 38          0.744582   6.254875        1.420140        0.854721
# 39          0.755133   5.772481        1.328702        0.816564
# 40          0.738920  11.149231        1.920578        1.290735
# 41          0.761242   5.908348        1.309012        0.870106
# 42          0.773834   5.616060        1.236520        0.787010
# 43          0.762035   5.408721        1.226125        0.820293
# 44          0.731216   6.212884        1.475131        0.865379
# 45          0.802249   3.096055        0.680272        0.573040
# 46          0.728144   4.833486        1.252339        0.765682
# 47          0.764835   5.996059        1.339663        0.846341
# 48          0.758822   3.652829        1.095300        0.606087
# 49          0.761727   5.109773        1.114189        0.755953
# 50          0.736162   6.976855        1.483972        0.969457
# 51          0.758887   6.749821        1.459810        0.912796
# 52          0.727396   7.288215        1.520090        1.025017
#
#     Std Perimeter  Std Eccentricity  Std Circularity
# 0        3.085005          0.146831         0.093520
# 1        3.400931          0.146093         0.104118
# 2        3.578504          0.148359         0.101595
# 3        3.337302          0.146834         0.103760
# 4        3.861904          0.147094         0.088999
# 5        4.391279          0.145831         0.094600
# 6        3.198260          0.148328         0.102046
# 7        4.066019          0.146962         0.107997
# 8        3.637754          0.152339         0.099539
# 9        3.457569          0.145862         0.105030
# 10       4.225444          0.147630         0.115521
# 11       4.633442          0.153524         0.103547
# 12       4.461146          0.148857         0.110138
# 13       3.447050          0.148470         0.104731
# 14       4.592675          0.155724         0.099294
# 15       3.491109          0.148263         0.106125
# 16       3.256403          0.152727         0.105992
# 17       3.187397          0.150596         0.103043
# 18       3.377772          0.153586         0.099865
# 19       3.423998          0.154580         0.095808
# 20       3.543081          0.152133         0.096397
# 21       2.862199          0.160411         0.096281
# 22       3.302954          0.144193         0.086062
# 23       4.968403          0.149025         0.099795
# 24       4.040528          0.151334         0.094418
# 25       5.146936          0.148840         0.127501
# 26       3.304482          0.151394         0.097059
# 27       3.906998          0.147590         0.101258
# 28       3.022307          0.146829         0.095731
# 29       3.312431          0.150907         0.098028
# 30       3.125651          0.147984         0.090661
# 31       3.734849          0.150244         0.092531
# 32       3.655375          0.151757         0.099538
# 33       3.788359          0.152428         0.101380
# 34       3.500574          0.162818         0.094020
# 35       2.979591          0.148373         0.091184
# 36       4.158208          0.148993         0.103364
# 37       3.745382          0.149176         0.095751
# 38       3.723199          0.150295         0.096472
# 39       3.557113          0.150094         0.094840
# 40       5.220003          0.151588         0.100976
# 41       3.560194          0.150274         0.095313
# 42       3.301406          0.150443         0.088209
# 43       3.279427          0.162747         0.100397
# 44       3.921383          0.147277         0.104294
# 45       1.959135          0.152816         0.074413
# 46       3.531476          0.147497         0.111303
# 47       3.528456          0.148264         0.094977
# 48       2.874245          0.145969         0.098560
# 49       3.045767          0.156968         0.087839
# 50       4.096864          0.147949         0.101541
# 51       3.831462          0.151185         0.094628
# 52       4.480303          0.152092         0.120214
