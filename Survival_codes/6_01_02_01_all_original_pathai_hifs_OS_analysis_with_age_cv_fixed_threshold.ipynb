# %%
# -----------------------------------------------------------------------------------------------------------------------
# Author: Ranjan Barman and dhrubas2
# Date: Jul 15, 2025
# Title: HIFs-based CoxPH Survival Analysis for BRCA Subtypes (HER2+, HR+, TNBC)
# Models: (2) All HIFs + Age (collinearity removal before CV, fold-wise normalization, Age not scaled)
# -----------------------------------------------------------------------------------------------------------------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from lifelines import CoxPHFitter
from lifelines.exceptions import ConvergenceWarning
import warnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Set working directory
_wpath_ = "/data/Lab_ruppin/Ranjan/HnE/"
os.chdir(_wpath_)

# Input/output paths
dataset_name = "TCGA_BRCA_FFPE"
data_file = f"{dataset_name}/outputs/PathAI/Survival_V2/BrcaBiomarkerStatusToPathAI_HIFsToSurvival.csv"
output_dir = os.path.join("/data/Ruppin_AI/BRCA_PIF/Ranjan/DataForFigures/Survival_V2", "HIFs")
os.makedirs(output_dir, exist_ok=True)

# Load data
data = pd.read_csv(data_file)

# Define HIFs (607 features)
HIFs = data.columns[4:611].tolist()
print("Total number of HIFs:", len(HIFs))

# Subtype filtering
tn = data[(data['HER2_Status'] == 'Negative') & (data['ER_Status'] == 'Negative') & (data['PR_Status'] == 'Negative')].copy()
her2 = data[data['HER2_Status'] == 'Positive'].copy()
hr = data[((data['ER_Status'] == 'Positive') | (data['PR_Status'] == 'Positive')) & (data['HER2_Status'] != 'Positive')].copy()

# Fixed collinearity filter function with threshold=0.65
def remove_highly_correlated_features(df, threshold=0.65):
    corr_matrix = df.corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    drop_cols = [col for col in upper.columns if any(upper[col] > threshold)]
    reduced_df = df.drop(columns=drop_cols)
    return reduced_df.columns.tolist()


# Main CV function
def coxph_5fold_cv_combined_km(df, subtype_name, feature_cols, survival_type='os', outputs_path=None):
    covariates = feature_cols + ['Age']
    time_col = f'{survival_type}_time'
    event_col = survival_type

    required_cols = covariates + ['sample_id', 'os_time', 'os', 'pfs_time', 'pfs']
    df = df[required_cols].dropna().copy()
    df['Subtype'] = subtype_name

    full_original = df.copy()
    df = df.rename(columns={time_col: 'Time', event_col: 'Event'})

    # Valid event checking
    max_retry = 100
    for retry in range(max_retry):
        kf = KFold(n_splits=5, shuffle=True, random_state=42 + retry)
        folds = list(kf.split(df))
        if all(df.iloc[test]['Event'].sum() > 0 for _, test in folds):
            break
    else:
        print(f"No valid CV split for {subtype_name} ({survival_type})")
        return None

    combined_df = []

    for fold_num, (train_idx, test_idx) in enumerate(folds, 1):
        train = df.iloc[train_idx].copy()
        test = df.iloc[test_idx].copy()

        try:
            train_covariates = train[feature_cols].copy()
            test_covariates = test[feature_cols].copy()

            # Scale HIFs only
            scaler = MinMaxScaler()
            train_scaled = scaler.fit_transform(train_covariates)
            test_scaled = scaler.transform(test_covariates)

            train_df = pd.DataFrame(train_scaled, columns=feature_cols, index=train.index)
            test_df = pd.DataFrame(test_scaled, columns=feature_cols, index=test.index)

            # Add raw Age, Time, Event
            train_df['Age'] = train['Age'].values
            train_df['Time'] = train['Time'].values
            train_df['Event'] = train['Event'].values
            test_df['Age'] = test['Age'].values

            # Fit CoxPH
            cph = CoxPHFitter()
            cph.fit(train_df, duration_col='Time', event_col='Event')

            test_risk = cph.predict_partial_hazard(test_df)

            # Store
            original_test_info = full_original.iloc[test_idx].copy()
            original_test_info[f"risk_score_{survival_type}"] = test_risk.values
            original_test_info['Fold'] = fold_num
            combined_df.append(original_test_info)

        except Exception as e:
            print(f"Fold {fold_num} failed for {subtype_name} ({survival_type}): {str(e)}")
            continue

    if not combined_df:
        print(f"All folds failed for {subtype_name} ({survival_type})")
        return None

    combined_df = pd.concat(combined_df, axis=0)
    return combined_df

# Merge helper
def merge_os_pfs(os_df, pfs_df):
    if os_df is None or pfs_df is None:
        print("Skipping merge due to missing input.")
        return None
    return pd.merge(
        os_df[['sample_id', 'os_time', 'os', 'Age', 'risk_score_os', 'Subtype']],
        pfs_df[['sample_id', 'pfs_time', 'pfs', 'risk_score_pfs']],
        on='sample_id', how='outer'
    )

# Apply collinearity filtering before CV per subtype

her2_hifs = remove_highly_correlated_features(her2[HIFs], threshold=0.65)
print(f"[HER2+ | Pre-CV] Fixed threshold = 0.65, Features retained = {len(her2_hifs)}")
print(f"[HER2+ | Retained Features] {her2_hifs}\n")

hr_hifs = remove_highly_correlated_features(hr[HIFs], threshold=0.65)
print(f"[HR+ | Pre-CV] Fixed threshold = 0.65, Features retained = {len(hr_hifs)}")
print(f"[HR+ | Retained Features] {hr_hifs}\n")

tnbc_hifs = remove_highly_correlated_features(tn[HIFs], threshold=0.65)
print(f"[TNBC | Pre-CV] Fixed threshold = 0.65, Features retained = {len(tnbc_hifs)}")
print(f"[TNBC | Retained Features] {tnbc_hifs}\n")



# Run survival analysis with filtered HIFs
her2_os_df   = coxph_5fold_cv_combined_km(her2, 'HER2+', her2_hifs, 'os', output_dir)
her2_pfs_df  = coxph_5fold_cv_combined_km(her2, 'HER2+', her2_hifs, 'pfs', output_dir)

hr_os_df     = coxph_5fold_cv_combined_km(hr, 'HR+', hr_hifs, 'os', output_dir)
hr_pfs_df    = coxph_5fold_cv_combined_km(hr, 'HR+', hr_hifs, 'pfs', output_dir)

tnbc_os_df   = coxph_5fold_cv_combined_km(tn, 'TNBC', tnbc_hifs, 'os', output_dir)
tnbc_pfs_df  = coxph_5fold_cv_combined_km(tn, 'TNBC', tnbc_hifs, 'pfs', output_dir)

# Merge results
her2_combined = merge_os_pfs(her2_os_df, her2_pfs_df)
hr_combined   = merge_os_pfs(hr_os_df, hr_pfs_df)
tnbc_combined = merge_os_pfs(tnbc_os_df, tnbc_pfs_df)

combined_list = [df for df in [her2_combined, hr_combined, tnbc_combined] if df is not None]
combined_all = pd.concat(combined_list, axis=0)
final_csv = os.path.join(output_dir, "All_Subtypes_AllSurvival_Combined_TestSamples_HIFs.csv")
combined_all.to_csv(final_csv, index=False)
# Out:
# Total number of HIFs: 607
# [HER2+ | Pre-CV] Fixed threshold = 0.65, Features retained = 44
# [HER2+ | Retained Features] ['AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE', 'AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE', 'AREA PROP [[EPITHELIAL] OVER [TUMOR]] IN [TISSUE]_HE', 'AREA PROP [[ESI_0080] OVER [TUMOR]] IN [TISSUE]_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF CANCER IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF CANCER IN ESI_0080_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN EPITHELIAL_HE', 'COUNT PROP [CANCER CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [LYMPHOCYTE CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE', 'COUNT PROP [[CANCER CELLS] OVER [[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]]] IN [EPITHELIAL]_HE', 'COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]]] IN [EPITHELIAL]_HE', 'DENSITY RATIO [FIBROBLAST CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: EXTENT OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: EXTENT OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: FRACTAL DIMENSION OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: LACUNARITY OF NECROSIS_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: TOTAL EULER NUMBER OF STROMA_HE']
#
# [HR+ | Pre-CV] Fixed threshold = 0.65, Features retained = 51
# [HR+ | Retained Features] ['AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE', 'AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE', 'AREA PROP [[EPITHELIAL] OVER [TUMOR]] IN [TISSUE]_HE', 'AREA PROP [[ESI_0080] OVER [TUMOR]] IN [TISSUE]_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF CANCER IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN ESI_0080_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF CANCER IN STROMA_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER SIZE MEAN OF PLASMA IN EPITHELIAL_HE', 'COUNT PROP [CANCER CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [FIBROBLAST CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE', 'COUNT PROP [FIBROBLAST CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [LYMPHOCYTE CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [MACROPHAGE CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [PLASMA CELLS] IN [[EPITHELIAL] OVER [STROMA]]_HE', 'COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]]] IN [EPITHELIAL]_HE', 'DENSITY RATIO [FIBROBLAST CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE', 'DENSITY RATIO [LYMPHOCYTE CELLS] IN [[ESI_0080] OVER [TUMOR]]_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: EXTENT OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: EXTENT OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: FRACTAL DIMENSION OF ESI_0080_HE', 'REGION PROPERTIES: FRACTAL DIMENSION OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: LACUNARITY OF NECROSIS_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: TOTAL EULER NUMBER OF EPITHELIAL_HE']
#
# [TNBC | Pre-CV] Fixed threshold = 0.65, Features retained = 39
# [TNBC | Retained Features] ['AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE', 'AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE', 'AREA PROP [[ESI_0080] OVER [TUMOR]] IN [TISSUE]_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF MACROPHAGE IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF CANCER IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF FIBROBLAST IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CALINSKI-HARABASZ INDEX OF PLASMA IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF MACROPHAGE IN EPITHELIAL_HE', 'CELL CLUSTERING PROPERTIES: CLUSTER EXTENT STANDARD DEVIATION OF PLASMA IN EPITHELIAL_HE', 'COUNT PROP [CANCER CELLS] IN [[EPITHELIAL] OVER [ESI_0080]]_HE', 'COUNT PROP [FIBROBLAST CELLS] IN [[ESI_0080] OVER [EPITHELIAL]]_HE', 'COUNT PROP [[[CANCER CELLS] SELECTED BY [MACROPHAGE_RADIUS_80]] OVER [[CANCER CELLS] SELECTED BY [PLASMA_RADIUS_80]]] IN [EPITHELIAL]_HE', 'DENSITY RATIO [LYMPHOCYTE CELLS] IN [[ESI_0080] OVER [STROMA]]_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: AVERAGE ECCENTRICITY OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: AVERAGE EXTENT OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF EPITHELIAL_HE', 'REGION PROPERTIES: ECCENTRICITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: EXTENT OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: FRACTAL DIMENSION OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: FRACTAL DIMENSION OF LARGEST REGION OF STROMA_HE', 'REGION PROPERTIES: LACUNARITY OF LARGEST REGION OF NECROSIS_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: NUMBER OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF EPITHELIAL_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF ESI_0080_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF ECCENTRICITIES OF SIGNIFICANT REGIONS OF TUMOR_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF NECROSIS_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF STROMA_HE', 'REGION PROPERTIES: STANDARD DEVIATION OF EXTENTS OF SIGNIFICANT REGIONS OF TUMOR_HE']

# %%
# Load combined for plotting
data_surv = pd.read_csv(final_csv)

import matplotlib.pyplot as plt
import seaborn as sns
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
from lifelines.plotting import add_at_risk_counts
from lifelines.utils import concordance_index

def normalize(x, q=0.1):
    qq = np.quantile(x, q=[q, 1 - q])
    xx = (x - qq[0]) / (qq[1] - qq[0])
    xx[xx < 0] = 0
    xx[xx > 1] = 1
    return xx

surv_grps = ["Low-risk", "High-risk"]
group_th = 0.5
norm_qq = 0.10
subtypes = np.unique(data_surv.Subtype)

fig_data5, fig_stat5 = {}, {}
for surv in ["os", "pfs"]:
    km_data = data_surv[["Subtype", f"risk_score_{surv}", surv, f"{surv}_time"]].copy()
    km_data["risk_score"] = normalize(km_data[f"risk_score_{surv}"], q=norm_qq)
    for sb in subtypes:
        km_grp = km_data[km_data.Subtype == sb].copy()
        km_grp["group"] = km_grp["risk_score"].apply(lambda x: surv_grps[int(x >= group_th)])
        km_grp = km_grp.groupby("group", observed=False).apply(lambda df: df)

        fig_data5[f"{surv}-{sb}"] = {
            grp: KaplanMeierFitter().fit(
                durations=km_grp.loc[grp, f"{surv}_time"],
                event_observed=km_grp.loc[grp, surv],
                label=grp
            )
            for grp in surv_grps
        }

        fig_stat5[f"{surv}-{sb}"] = {
            "Cidx": concordance_index(
                event_times=km_data.loc[km_data.Subtype == sb, f"{surv}_time"],
                event_observed=km_data.loc[km_data.Subtype == sb, surv],
                predicted_scores=-km_data.loc[km_data.Subtype == sb, "risk_score"]
            ),
            "pval": logrank_test(
                durations_A=km_grp.loc[surv_grps[0], f"{surv}_time"],
                event_observed_A=km_grp.loc[surv_grps[0], surv],
                durations_B=km_grp.loc[surv_grps[1], f"{surv}_time"],
                event_observed_B=km_grp.loc[surv_grps[1], surv]
            ).p_value
        }

import matplotlib.pyplot as plt

#%% make fig 5.

sns.set_style("ticks")
plt.rcParams.update({
    "xtick.major.size": 8, "xtick.major.width": 2, 
    "ytick.major.size": 8, "ytick.major.width": 2, 
    "xtick.bottom": True, "ytick.left": True, 
    "axes.spines.top": False, "axes.spines.right": False, 
    "axes.linewidth": 2, "axes.edgecolor": "#000000", 
    "grid.linewidth": 1, "grid.color": "#000000", "grid.alpha": 0.8, 
    "legend.frameon": False, "legend.edgecolor": "#000000", 
    "legend.framealpha": 0.9, "legend.markerscale": 1.2, 
    "font.family": "sans"})

colors     = ["#E08DAC", "#7595D0", "#75D0B0", "#B075D0", "#C3D075", 
              "#FFC72C", "#708090", "#A9A9A9", "#000000"]
colors     = colors[:2][::-1]

fontdict   = {"label": {"size": 12, "weight": "regular"}, 
              "sbttl": {"size": 14, "weight": "bold"}, 
              "title": {"size": 16, "weight": "bold"}, 
              "super": {"size": 20, "weight": "bold"}, 
              "panel": {"size": 36, "weight": "bold"}}

lineprop   = {"ls": "-", "lw": 2}

fig_llocs5 = [0.96, 0.46]

fig5, ax5 = plt.subplots(figsize = (16, 10), nrows = 2, ncols = 3, sharey = True)
# ax5 = dict(zip([["A1", "A2", "A3"], ["B1", "B2", "B3"]], ax5))

for i, (surv, lbl) in enumerate(zip(["pfs", "os"], ["A", "B"])):
    for j, sb in enumerate(subtypes):
        dat, stat = fig_data5[f"{surv}-{sb}"], pd.Series(fig_stat5[f"{surv}-{sb}"])
        ax = ax5[i, j]
        for k, (grp, mdl) in enumerate(dat.items()):
            ax = mdl.plot(show_censors = True, ci_show = True, color = colors[k], 
                          ci_alpha = 0.15, ax = ax, **lineprop)
        ax.text(x = 250, y = 0.05, 
                s = f"C-index = {stat.Cidx:0.3f}\nLog-rank $P$ = {stat.pval:0.3f}", 
                **fontdict["label"]);
        add_at_risk_counts(*dat.values(), labels = list(dat.keys()), 
                           rows_to_show = None, ax = ax, **fontdict["label"]);
        sns.despine(ax = ax, offset = 0, trim = False);

        ax.set_ylim([-0.1, 1.1]);
        ax.tick_params(axis = "both", labelsize = fontdict["label"]["size"]);
        if (i, j) == (1, 2):
            ax.legend(loc = (1.12, 0.8), title = "Risk group", prop = fontdict["label"], 
                      title_fontproperties = fontdict["title"])
        else:
            ax.legend([ ], [ ]);

        ax.set_xlabel("Time in days", y = 0.025, **fontdict["label"]);
        if j == 0:
            ax.set_ylabel(f"{surv.upper()} probability", x = 0.025, **fontdict["label"]);
        
        if i == 0:
            ax.set_title(f"{sb} (n = {data_surv.Subtype.eq(sb).sum():,})", wrap = True, 
                         y = 1.1, **fontdict["title"]);

    fig5.text(x = 0.02, y = fig_llocs5[i], s = lbl, **fontdict["panel"]);


fig5.tight_layout(h_pad = 2)
plt.show()
final_csv
# Out:
# '/data/Ruppin_AI/BRCA_PIF/Ranjan/DataForFigures/Survival_V2/HIFs/All_Subtypes_AllSurvival_Combined_TestSamples_HIFs.csv'

# %%
data_surv
# Out:
#         sample_id  os_time  os  Age  risk_score_os Subtype  pfs_time  pfs  \
# 0    TCGA-A1-A0SN     1196   0   50       2.822856   HER2+      1196    0
# 1    TCGA-A2-A04W     3102   0   50       0.065248   HER2+      3102    0
# 2    TCGA-A2-A0SY     1347   0   62       0.081617   HER2+      1347    0
# 3    TCGA-A2-A1G1      584   0   85   14263.441360   HER2+       584    0
# 4    TCGA-AQ-A04L     3957   0   48      62.768974   HER2+      3957    0
# ..            ...      ...  ..  ...            ...     ...       ...  ...
# 551  TCGA-E2-A1AZ     2329   0   63       0.075788    TNBC      2329    0
# 552  TCGA-E2-A1LK      266   1   84      27.861164    TNBC       155    1
# 553  TCGA-E2-A1LL     1309   0   73       0.038127    TNBC      1303    1
# 554  TCGA-E2-A1LS     1604   0   46       8.186562    TNBC      1604    0
# 555  TCGA-EW-A1PB      608   0   70       3.296395    TNBC       608    0
#
#      risk_score_pfs
# 0          0.014342
# 1          6.940305
# 2          1.223757
# 3          7.287655
# 4          0.415385
# ..              ...
# 551        0.206111
# 552      202.255047
# 553        0.049655
# 554        1.960283
# 555        6.512981
#
# [556 rows x 9 columns]
