# %%
#### -----------------------------------------------------------------------------------------------------------------------------------------
#### author: Ranjan Barman, date: Aug 27, 2024
#### Mapped PathAI metadata to nuHIFs data to TCGA biomarker status
#### ------------------------------------------------------------------------------------------------------------------------------------------
import os, sys, pickle, bz2
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from time import time 
from tqdm import tqdm

_wpath_ = "/data/Lab_ruppin/Ranjan/HnE/"        # set working directory as the parent directory where all datasets are saved
os.chdir(_wpath_)

print(f"working directory = {_wpath_}\n")
# Out:
# working directory = /data/Lab_ruppin/Ranjan/HnE/

# %%
#%% get TCGA_BRCA subtypes & input HIF features data.

dataset_name = "PA_NUHIF_BRCA"

data_path    = [f"{dataset_name}/data/"]
data_files   = ["PathAI_BRCA_MetaData.xlsx",
                "PathAI_BRCA_NuHIFs.xlsx"]

# Data directories & files
dataset_name1 = "PA_HIF_BRCA"
feature_name1 = "HIF"
outcome_names = ["HER2_Status", "PR_Status", "ER_Status"]

data_path1 = f"{dataset_name1}/outputs_clinical/"
data_file1 = "TCGA_BRCA_Subtypes_clinical.tsv"

## create directories to save outputs
outputs_path = f"{dataset_name}/outputs_biomarker_status/"
os.makedirs(outputs_path, exist_ok = True)

#read metadata file of PathAI 
PathAI_meta_data = pd.read_excel(data_path[0] + data_files[0])

#read nuHIF file of PathAI 
PathAI_nuHIFs_data = pd.read_excel(data_path[0] + data_files[1])


# samples
PathAI_meta_data.head()
PathAI_nuHIFs_data.head()
# Out:
#    H & E_ID  IQR[(UNKNOWN)_NUCLEUS_AREA]_H & E  \
# 0     26524                          24.361557
# 1     75662                          18.216915
# 2     80086                          15.960288
# 3     80092                          19.491276
# 4     80099                          13.616371
#
#    IQR[(UNKNOWN)_NUCLEUS_CIRCULARITY]_H & E  \
# 0                                  0.318226
# 1                                  0.312133
# 2                                  0.223923
# 3                                  0.354271
# 4                                  0.205485
#
#    IQR[(UNKNOWN)_NUCLEUS_ECCENTRICITY]_H & E  \
# 0                                   0.187292
# 1                                   0.221327
# 2                                   0.200768
# 3                                   0.221223
# 4                                   0.224691
#
#    IQR[(UNKNOWN)_NUCLEUS_MAJOR_AXIS_LENGTH]_H & E  \
# 0                                        4.619149
# 1                                        3.508829
# 2                                        3.372420
# 3                                        3.827091
# 4                                        3.068618
#
#    IQR[(UNKNOWN)_NUCLEUS_MAX_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                           0.290089
# 1                                           0.227006
# 2                                           0.169655
# 3                                           0.183165
# 4                                           0.182500
#
#    IQR[(UNKNOWN)_NUCLEUS_MAX_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                           0.141176
# 1                                           0.172549
# 2                                           0.156863
# 3                                           0.211765
# 4                                           0.164706
#
#    IQR[(UNKNOWN)_NUCLEUS_MAX_LAB_CHANNEL_A]_H & E  \
# 0                                        0.031373
# 1                                        0.031373
# 2                                        0.023529
# 3                                        0.027451
# 4                                        0.019608
#
#    IQR[(UNKNOWN)_NUCLEUS_MAX_LAB_CHANNEL_B]_H & E  \
# 0                                        0.039216
# 1                                        0.043137
# 2                                        0.031373
# 3                                        0.031373
# 4                                        0.039216
#
#    IQR[(UNKNOWN)_NUCLEUS_MEAN_GRAYSCALE_CHANNEL_GRAY]_H & E  ...  \
# 0                                           0.167744         ...
# 1                                           0.131993         ...
# 2                                           0.173218         ...
# 3                                           0.163543         ...
# 4                                           0.143585         ...
#
#    STD[PLASMA_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                           0.088273
# 1                                           0.071921
# 2                                           0.049966
# 3                                           0.070411
# 4                                           0.083541
#
#    STD[PLASMA_NUCLEUS_MIN_LAB_CHANNEL_A]_H & E  \
# 0                                     0.012206
# 1                                     0.020229
# 2                                     0.017867
# 3                                     0.017813
# 4                                     0.024922
#
#    STD[PLASMA_NUCLEUS_MIN_LAB_CHANNEL_B]_H & E  \
# 0                                     0.017756
# 1                                     0.025833
# 2                                     0.020963
# 3                                     0.016830
# 4                                     0.024043
#
#    STD[PLASMA_NUCLEUS_ORIENTATION]_H & E  STD[PLASMA_NUCLEUS_PERIMETER]_H & E  \
# 0                               1.213632                             4.311863
# 1                               0.944390                             3.499922
# 2                               0.875600                             3.206401
# 3                               0.907405                             3.726454
# 4                               0.927892                             3.492507
#
#    STD[PLASMA_NUCLEUS_SOLIDITY]_H & E  \
# 0                            0.010056
# 1                            0.021072
# 2                            0.013669
# 3                            0.018573
# 4                            0.020536
#
#    STD[PLASMA_NUCLEUS_STD_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                           0.020215
# 1                                           0.017867
# 2                                           0.021685
# 3                                           0.018950
# 4                                           0.021883
#
#    STD[PLASMA_NUCLEUS_STD_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                           0.018900
# 1                                           0.015063
# 2                                           0.012737
# 3                                           0.016912
# 4                                           0.020422
#
#    STD[PLASMA_NUCLEUS_STD_LAB_CHANNEL_A]_H & E  \
# 0                                     0.002124
# 1                                     0.003185
# 2                                     0.002807
# 3                                     0.002859
# 4                                     0.003853
#
#    STD[PLASMA_NUCLEUS_STD_LAB_CHANNEL_B]_H & E
# 0                                     0.003534
# 1                                     0.005979
# 2                                     0.004732
# 3                                     0.004037
# 4                                     0.005755
#
# [5 rows x 673 columns]

# %%
# 'H & E_ID' is the column name in df1 and 'H & E_ID' is the column name in df2
# Adjust these column names to match the actual column names in your CSV files
merged_df = pd.merge(PathAI_meta_data, PathAI_nuHIFs_data, left_on='H & E_ID', right_on='H & E_ID', how='inner')
merged_df
# Out:
#      H & E_ID  gender vital_status  aneuploidy_score  hrd_score  \
# 0       26524  FEMALE        Alive               0.0        0.0
# 1       75662  FEMALE         Dead               3.0       10.0
# 2       80086  FEMALE        Alive               NaN        NaN
# 3       80092  FEMALE        Alive              10.0       12.0
# 4       80099  FEMALE        Alive               NaN        NaN
# ..        ...     ...          ...               ...        ...
# 881     91896  FEMALE        Alive               6.0        9.0
# 882     91897  FEMALE        Alive              11.0       17.0
# 883     91901  FEMALE        Alive               NaN        NaN
# 884     91908  FEMALE        Alive               3.0       11.0
# 885     91916  FEMALE        Alive              18.0       42.0
#
#      genome_doublings  os  os_time  pfs  pfs_time  ...  \
# 0                 0.0   0        8    0         8  ...
# 1                 0.0   1     2009    1      2009  ...
# 2                 NaN   0      446    0       446  ...
# 3                 0.0   0      433    0       433  ...
# 4                 NaN   0      385    0       385  ...
# ..                ...  ..      ...  ...       ...  ...
# 881               0.0   0     1150    0      1150  ...
# 882               1.0   0      317    0       317  ...
# 883               NaN   0      849    1       681  ...
# 884               0.0   0      172    0       172  ...
# 885               1.0   0     2329    0      2329  ...
#
#      STD[PLASMA_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.088273
# 1                                             0.071921
# 2                                             0.049966
# 3                                             0.070411
# 4                                             0.083541
# ..                                                 ...
# 881                                           0.079903
# 882                                           0.074087
# 883                                           0.088994
# 884                                           0.074113
# 885                                           0.062591
#
#     STD[PLASMA_NUCLEUS_MIN_LAB_CHANNEL_A]_H & E  \
# 0                                      0.012206
# 1                                      0.020229
# 2                                      0.017867
# 3                                      0.017813
# 4                                      0.024922
# ..                                          ...
# 881                                    0.018760
# 882                                    0.023444
# 883                                    0.018527
# 884                                    0.016598
# 885                                    0.020012
#
#     STD[PLASMA_NUCLEUS_MIN_LAB_CHANNEL_B]_H & E  \
# 0                                      0.017756
# 1                                      0.025833
# 2                                      0.020963
# 3                                      0.016830
# 4                                      0.024043
# ..                                          ...
# 881                                    0.022747
# 882                                    0.021649
# 883                                    0.015926
# 884                                    0.023222
# 885                                    0.018900
#
#      STD[PLASMA_NUCLEUS_ORIENTATION]_H & E  \
# 0                                 1.213632
# 1                                 0.944390
# 2                                 0.875600
# 3                                 0.907405
# 4                                 0.927892
# ..                                     ...
# 881                               0.884152
# 882                               0.889008
# 883                               0.955501
# 884                               0.901696
# 885                               0.870905
#
#     STD[PLASMA_NUCLEUS_PERIMETER]_H & E  STD[PLASMA_NUCLEUS_SOLIDITY]_H & E  \
# 0                              4.311863                            0.010056
# 1                              3.499922                            0.021072
# 2                              3.206401                            0.013669
# 3                              3.726454                            0.018573
# 4                              3.492507                            0.020536
# ..                                  ...                                 ...
# 881                            3.281347                            0.017079
# 882                            3.279637                            0.015747
# 883                            3.587269                            0.017242
# 884                            3.542597                            0.024372
# 885                            3.356451                            0.014588
#
#      STD[PLASMA_NUCLEUS_STD_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.020215
# 1                                             0.017867
# 2                                             0.021685
# 3                                             0.018950
# 4                                             0.021883
# ..                                                 ...
# 881                                           0.020732
# 882                                           0.020919
# 883                                           0.022089
# 884                                           0.018528
# 885                                           0.018661
#
#      STD[PLASMA_NUCLEUS_STD_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.018900
# 1                                             0.015063
# 2                                             0.012737
# 3                                             0.016912
# 4                                             0.020422
# ..                                                 ...
# 881                                           0.018555
# 882                                           0.019710
# 883                                           0.017854
# 884                                           0.014444
# 885                                           0.017341
#
#      STD[PLASMA_NUCLEUS_STD_LAB_CHANNEL_A]_H & E  \
# 0                                       0.002124
# 1                                       0.003185
# 2                                       0.002807
# 3                                       0.002859
# 4                                       0.003853
# ..                                           ...
# 881                                     0.004168
# 882                                     0.003739
# 883                                     0.003783
# 884                                     0.003381
# 885                                     0.002988
#
#      STD[PLASMA_NUCLEUS_STD_LAB_CHANNEL_B]_H & E
# 0                                       0.003534
# 1                                       0.005979
# 2                                       0.004732
# 3                                       0.004037
# 4                                       0.005755
# ..                                           ...
# 881                                     0.005220
# 882                                     0.006685
# 883                                     0.004299
# 884                                     0.005702
# 885                                     0.004411
#
# [886 rows x 687 columns]

# %%
# Define the patterns to look for at the start of column names
start_patterns = [
    'MEAN[CANCER', 
    'MEAN[FIBROBLAST', 
    'MEAN[LYMPHOCYTE', 
    'STD[CANCER', 
    'STD[FIBROBLAST', 
    'STD[LYMPHOCYTE'
]

# Define the strings that should be present in the column names
required_strings = [
    'AREA', 
    'MAJOR_AXIS_LENGTH', 
    'MINOR_AXIS_LENGTH', 
    'PERIMETER', 
    'CIRCULARITY', 
    'ECCENTRICITY', 
    'SOLIDITY', 
    'STD_GRAYSCALE_CHANNEL_GRAY', 
    'STD_HSV_CHANNEL_SATURATION', 
    'STD_LAB_CHANNEL_A', 
    'STD_LAB_CHANNEL_B', 
    'MIN_GRAYSCALE_CHANNEL_GRAY', 
    'MIN_HSV_CHANNEL_SATURATION', 
    'MEAN_LAB_CHANNEL_A', 
    'MEAN_LAB_CHANNEL_B'
]

# Extract columns that start with the specified patterns and contain any of the required strings
cancer_fibroblast_lymphocyte_columns = [
    col for col in merged_df.columns if 
    any(col.startswith(pattern) for pattern in start_patterns) and 
    any(req_str in col for req_str in required_strings)
]

# Ensure 'bcr_patient_barcode' and 'subtype' are present in the DataFrame
# Add them to the start of the filtered columns
essential_columns = ['bcr_patient_barcode']

# Combine the essential columns with cancer_fibroblast_lymphocyte_columns
final_columns = essential_columns + cancer_fibroblast_lymphocyte_columns


# Extract the relevant data
extracted_subtype_nuHIFs = merged_df[final_columns]

#Rename the bcr_patient_barcode column to sample
extracted_subtype_nuHIFs = extracted_subtype_nuHIFs.rename(columns={'bcr_patient_barcode': 'sample'})

extracted_subtype_nuHIFs
# Out:
#            sample  MEAN[CANCER_NUCLEUS_AREA]_H & E  \
# 0    TCGA-PL-A8LY                        37.870327
# 1    TCGA-BH-A18S                        38.068584
# 2    TCGA-A7-A4SC                        32.376812
# 3    TCGA-D8-A1Y2                        34.365021
# 4    TCGA-C8-A12V                        39.071213
# ..            ...                              ...
# 881  TCGA-AR-A1AS                        47.793850
# 882  TCGA-C8-A1HL                        48.468864
# 883  TCGA-LQ-A4E4                        40.482265
# 884  TCGA-AN-A0FF                        33.570347
# 885  TCGA-E2-A1AZ                        43.516521
#
#      MEAN[CANCER_NUCLEUS_CIRCULARITY]_H & E  \
# 0                                  0.752129
# 1                                  0.803479
# 2                                  0.795850
# 3                                  0.788894
# 4                                  0.784081
# ..                                      ...
# 881                                0.759587
# 882                                0.763141
# 883                                0.776762
# 884                                0.766258
# 885                                0.798199
#
#      MEAN[CANCER_NUCLEUS_ECCENTRICITY]_H & E  \
# 0                                   0.740944
# 1                                   0.667058
# 2                                   0.679380
# 3                                   0.682284
# 4                                   0.686660
# ..                                       ...
# 881                                 0.734216
# 882                                 0.713281
# 883                                 0.680984
# 884                                 0.702174
# 885                                 0.678485
#
#      MEAN[CANCER_NUCLEUS_MAJOR_AXIS_LENGTH]_H & E  \
# 0                                        9.088960
# 1                                        8.564404
# 2                                        7.991061
# 3                                        8.251385
# 4                                        8.686616
# ..                                            ...
# 881                                     10.062342
# 882                                      9.954347
# 883                                      8.898990
# 884                                      8.304225
# 885                                      9.184370
#
#      MEAN[CANCER_NUCLEUS_MEAN_LAB_CHANNEL_A]_H & E  \
# 0                                         0.594218
# 1                                         0.610667
# 2                                         0.578427
# 3                                         0.602840
# 4                                         0.600544
# ..                                             ...
# 881                                       0.616858
# 882                                       0.607404
# 883                                       0.597539
# 884                                       0.594162
# 885                                       0.605873
#
#      MEAN[CANCER_NUCLEUS_MEAN_LAB_CHANNEL_B]_H & E  \
# 0                                         0.405748
# 1                                         0.416995
# 2                                         0.431150
# 3                                         0.412379
# 4                                         0.413815
# ..                                             ...
# 881                                       0.429411
# 882                                       0.399618
# 883                                       0.422517
# 884                                       0.405842
# 885                                       0.418697
#
#      MEAN[CANCER_NUCLEUS_MINOR_AXIS_LENGTH]_H & E  \
# 0                                        5.675256
# 1                                        6.018374
# 2                                        5.526413
# 3                                        5.653194
# 4                                        5.919993
# ..                                            ...
# 881                                      6.332615
# 882                                      6.505261
# 883                                      6.147808
# 884                                      5.511056
# 885                                      6.313754
#
#      MEAN[CANCER_NUCLEUS_MIN_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.135048
# 1                                             0.130621
# 2                                             0.226366
# 3                                             0.151201
# 4                                             0.170848
# ..                                                 ...
# 881                                           0.131279
# 882                                           0.147581
# 883                                           0.093983
# 884                                           0.127157
# 885                                           0.190583
#
#      MEAN[CANCER_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  ...  \
# 0                                             0.313856      ...
# 1                                             0.255800      ...
# 2                                             0.133215      ...
# 3                                             0.219145      ...
# 4                                             0.118866      ...
# ..                                                 ...      ...
# 881                                           0.251252      ...
# 882                                           0.205403      ...
# 883                                           0.201440      ...
# 884                                           0.241588      ...
# 885                                           0.127519      ...
#
#      STD[LYMPHOCYTE_NUCLEUS_MEAN_LAB_CHANNEL_B]_H & E  \
# 0                                            0.009443
# 1                                            0.010207
# 2                                            0.006967
# 3                                            0.007224
# 4                                            0.017781
# ..                                                ...
# 881                                          0.008048
# 882                                          0.013180
# 883                                          0.009824
# 884                                          0.007930
# 885                                          0.007995
#
#      STD[LYMPHOCYTE_NUCLEUS_MINOR_AXIS_LENGTH]_H & E  \
# 0                                           0.957306
# 1                                           0.837812
# 2                                           0.841132
# 3                                           0.801812
# 4                                           0.727386
# ..                                               ...
# 881                                         0.731268
# 882                                         0.781547
# 883                                         0.876126
# 884                                         0.731670
# 885                                         0.687270
#
#      STD[LYMPHOCYTE_NUCLEUS_MIN_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.040454
# 1                                             0.040262
# 2                                             0.047287
# 3                                             0.051126
# 4                                             0.057589
# ..                                                 ...
# 881                                           0.040083
# 882                                           0.060307
# 883                                           0.033074
# 884                                           0.033249
# 885                                           0.053845
#
#      STD[LYMPHOCYTE_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.089436
# 1                                             0.074601
# 2                                             0.046261
# 3                                             0.065717
# 4                                             0.072681
# ..                                                 ...
# 881                                           0.078726
# 882                                           0.072402
# 883                                           0.090117
# 884                                           0.076339
# 885                                           0.055913
#
#      STD[LYMPHOCYTE_NUCLEUS_PERIMETER]_H & E  \
# 0                                   3.992348
# 1                                   3.188401
# 2                                   3.218295
# 3                                   3.289017
# 4                                   3.023650
# ..                                       ...
# 881                                 3.091555
# 882                                 3.213238
# 883                                 3.759877
# 884                                 3.251431
# 885                                 2.680880
#
#      STD[LYMPHOCYTE_NUCLEUS_SOLIDITY]_H & E  \
# 0                                  0.058896
# 1                                  0.018339
# 2                                  0.017572
# 3                                  0.019602
# 4                                  0.019152
# ..                                      ...
# 881                                0.018503
# 882                                0.018057
# 883                                0.025011
# 884                                0.021967
# 885                                0.015694
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.024395
# 1                                             0.020380
# 2                                             0.021008
# 3                                             0.020905
# 4                                             0.021876
# ..                                                 ...
# 881                                           0.022948
# 882                                           0.022812
# 883                                           0.023226
# 884                                           0.022200
# 885                                           0.020625
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.020367
# 1                                             0.018566
# 2                                             0.015158
# 3                                             0.020543
# 4                                             0.021078
# ..                                                 ...
# 881                                           0.024541
# 882                                           0.023739
# 883                                           0.022701
# 884                                           0.018067
# 885                                           0.021181
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_A]_H & E  \
# 0                                           0.004481
# 1                                           0.003950
# 2                                           0.003017
# 3                                           0.003352
# 4                                           0.004379
# ..                                               ...
# 881                                         0.003706
# 882                                         0.004350
# 883                                         0.003968
# 884                                         0.003412
# 885                                         0.003558
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_B]_H & E
# 0                                           0.005192
# 1                                           0.007380
# 2                                           0.005687
# 3                                           0.004804
# 4                                           0.006619
# ..                                               ...
# 881                                         0.005923
# 882                                         0.006741
# 883                                         0.004428
# 884                                         0.007163
# 885                                         0.005208
#
# [886 rows x 91 columns]

# %%
# TCGA BRCA sub type data
tcga_subtypes_data   = pd.read_table(data_path1 + data_file1, sep = "\t")

# Remove '-01' from each sampleID to match with HIF Sample ID
tcga_subtypes_data['sampleID'] = tcga_subtypes_data['sampleID'].str.replace('-01', '', regex=False)

# Rename the columns in tcga_subtypes_data
tcga_subtypes_data = tcga_subtypes_data.rename(columns={"HER2_Final_Status_nature2012": "HER2_Status", "PR_Status_nature2012": "PR_Status", "ER_Status_nature2012": "ER_Status"})

tcga_subtypes_data
# Out:
#          sampleID HER2_Status PR_Status ER_Status  BRCA_Subtypes
# 0    TCGA-A1-A0SB    Negative  Negative  Positive    HR Positive
# 1    TCGA-A1-A0SD    Negative  Positive  Positive    HR Positive
# 2    TCGA-A1-A0SE    Negative  Positive  Positive    HR Positive
# 3    TCGA-A1-A0SF    Negative  Positive  Positive    HR Positive
# 4    TCGA-A1-A0SG    Negative  Positive  Positive    HR Positive
# ..            ...         ...       ...       ...            ...
# 739  TCGA-EW-A1PB    Negative  Negative  Negative           TNBC
# 740  TCGA-EW-A1PD    Positive  Positive  Positive  HER2 Positive
# 741  TCGA-EW-A1PE    Negative  Positive  Positive    HR Positive
# 742  TCGA-EW-A1PF    Negative  Positive  Positive    HR Positive
# 743  TCGA-EW-A1PG    Negative  Positive  Positive    HR Positive
#
# [744 rows x 5 columns]

# %%
# '# 'sample' is the column name in df1 and 'sampleID' is the column name in df2
# Adjust these column names to match the actual column names in your CSV files
merged_df1 = pd.merge(extracted_subtype_nuHIFs, tcga_subtypes_data, left_on='sample', right_on='sampleID', how='inner')

merged_df1
# Out:
#            sample  MEAN[CANCER_NUCLEUS_AREA]_H & E  \
# 0    TCGA-D8-A1Y2                        34.365021
# 1    TCGA-C8-A12V                        39.071213
# 2    TCGA-EW-A1P6                        38.241444
# 3    TCGA-AR-A1AJ                        37.569180
# 4    TCGA-E2-A15S                        37.934071
# ..            ...                              ...
# 577  TCGA-A2-A04N                        40.167149
# 578  TCGA-AR-A1AS                        47.793850
# 579  TCGA-C8-A1HL                        48.468864
# 580  TCGA-AN-A0FF                        33.570347
# 581  TCGA-E2-A1AZ                        43.516521
#
#      MEAN[CANCER_NUCLEUS_CIRCULARITY]_H & E  \
# 0                                  0.788894
# 1                                  0.784081
# 2                                  0.810570
# 3                                  0.756555
# 4                                  0.813011
# ..                                      ...
# 577                                0.786355
# 578                                0.759587
# 579                                0.763141
# 580                                0.766258
# 581                                0.798199
#
#      MEAN[CANCER_NUCLEUS_ECCENTRICITY]_H & E  \
# 0                                   0.682284
# 1                                   0.686660
# 2                                   0.643006
# 3                                   0.742634
# 4                                   0.654944
# ..                                       ...
# 577                                 0.661289
# 578                                 0.734216
# 579                                 0.713281
# 580                                 0.702174
# 581                                 0.678485
#
#      MEAN[CANCER_NUCLEUS_MAJOR_AXIS_LENGTH]_H & E  \
# 0                                        8.251385
# 1                                        8.686616
# 2                                        8.426938
# 3                                        9.057047
# 4                                        8.453368
# ..                                            ...
# 577                                      8.731260
# 578                                     10.062342
# 579                                      9.954347
# 580                                      8.304225
# 581                                      9.184370
#
#      MEAN[CANCER_NUCLEUS_MEAN_LAB_CHANNEL_A]_H & E  \
# 0                                         0.602840
# 1                                         0.600544
# 2                                         0.606436
# 3                                         0.615502
# 4                                         0.610344
# ..                                             ...
# 577                                       0.652192
# 578                                       0.616858
# 579                                       0.607404
# 580                                       0.594162
# 581                                       0.605873
#
#      MEAN[CANCER_NUCLEUS_MEAN_LAB_CHANNEL_B]_H & E  \
# 0                                         0.412379
# 1                                         0.413815
# 2                                         0.413195
# 3                                         0.423559
# 4                                         0.407051
# ..                                             ...
# 577                                       0.405773
# 578                                       0.429411
# 579                                       0.399618
# 580                                       0.405842
# 581                                       0.418697
#
#      MEAN[CANCER_NUCLEUS_MINOR_AXIS_LENGTH]_H & E  \
# 0                                        5.653194
# 1                                        5.919993
# 2                                        6.092019
# 3                                        5.576258
# 4                                        6.011490
# ..                                            ...
# 577                                      6.183293
# 578                                      6.332615
# 579                                      6.505261
# 580                                      5.511056
# 581                                      6.313754
#
#      MEAN[CANCER_NUCLEUS_MIN_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.151201
# 1                                             0.170848
# 2                                             0.189393
# 3                                             0.119670
# 4                                             0.222011
# ..                                                 ...
# 577                                           0.197981
# 578                                           0.131279
# 579                                           0.147581
# 580                                           0.127157
# 581                                           0.190583
#
#      MEAN[CANCER_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  ...  \
# 0                                             0.219145      ...
# 1                                             0.118866      ...
# 2                                             0.159895      ...
# 3                                             0.310942      ...
# 4                                             0.180906      ...
# ..                                                 ...      ...
# 577                                           0.310632      ...
# 578                                           0.251252      ...
# 579                                           0.205403      ...
# 580                                           0.241588      ...
# 581                                           0.127519      ...
#
#      STD[LYMPHOCYTE_NUCLEUS_SOLIDITY]_H & E  \
# 0                                  0.019602
# 1                                  0.019152
# 2                                  0.016114
# 3                                  0.020363
# 4                                  0.012161
# ..                                      ...
# 577                                0.016338
# 578                                0.018503
# 579                                0.018057
# 580                                0.021967
# 581                                0.015694
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.020905
# 1                                             0.021876
# 2                                             0.020894
# 3                                             0.021541
# 4                                             0.020599
# ..                                                 ...
# 577                                           0.021173
# 578                                           0.022948
# 579                                           0.022812
# 580                                           0.022200
# 581                                           0.020625
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.020543
# 1                                             0.021078
# 2                                             0.018527
# 3                                             0.025585
# 4                                             0.023713
# ..                                                 ...
# 577                                           0.020896
# 578                                           0.024541
# 579                                           0.023739
# 580                                           0.018067
# 581                                           0.021181
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_A]_H & E  \
# 0                                           0.003352
# 1                                           0.004379
# 2                                           0.004438
# 3                                           0.003586
# 4                                           0.003215
# ..                                               ...
# 577                                         0.004519
# 578                                         0.003706
# 579                                         0.004350
# 580                                         0.003412
# 581                                         0.003558
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_B]_H & E      sampleID  \
# 0                                           0.004804  TCGA-D8-A1Y2
# 1                                           0.006619  TCGA-C8-A12V
# 2                                           0.006021  TCGA-EW-A1P6
# 3                                           0.006296  TCGA-AR-A1AJ
# 4                                           0.005068  TCGA-E2-A15S
# ..                                               ...           ...
# 577                                         0.003546  TCGA-A2-A04N
# 578                                         0.005923  TCGA-AR-A1AS
# 579                                         0.006741  TCGA-C8-A1HL
# 580                                         0.007163  TCGA-AN-A0FF
# 581                                         0.005208  TCGA-E2-A1AZ
#
#      HER2_Status  PR_Status  ER_Status  BRCA_Subtypes
# 0       Negative   Positive   Positive    HR Positive
# 1       Negative   Negative   Negative           TNBC
# 2       Negative   Positive   Positive    HR Positive
# 3       Negative   Negative   Positive    HR Positive
# 4       Negative   Negative   Positive    HR Positive
# ..           ...        ...        ...            ...
# 577     Negative   Positive   Positive    HR Positive
# 578     Negative   Positive   Positive    HR Positive
# 579     Positive   Negative   Positive  HER2 Positive
# 580     Negative   Positive   Positive    HR Positive
# 581     Negative   Negative   Negative           TNBC
#
# [582 rows x 96 columns]

# %%
# Remove the 'sampleID' column
merged_df1 = merged_df1.drop(columns=['sampleID'])

# Define the desired order for the specified columns
desired_columns = ['HER2_Status', 'PR_Status', 'ER_Status', 'BRCA_Subtypes']

# Get the list of existing columns excluding the desired columns
remaining_columns = [col for col in merged_df1.columns if col not in desired_columns and col != 'sample']

# Reorder the columns: 'sample' followed by desired_columns and then the remaining columns
new_column_order = ['sample'] + desired_columns + remaining_columns

# Apply the new column order to the DataFrame
merged_df1 = merged_df1[new_column_order]

# Rename 'sample' to 'sample_id'
merged_df1 = merged_df1.rename(columns={'sample': 'sample_id'})
merged_df1

# Display the resulting DataFrame
merged_df1
# Out:
#         sample_id HER2_Status PR_Status ER_Status  BRCA_Subtypes  \
# 0    TCGA-D8-A1Y2    Negative  Positive  Positive    HR Positive
# 1    TCGA-C8-A12V    Negative  Negative  Negative           TNBC
# 2    TCGA-EW-A1P6    Negative  Positive  Positive    HR Positive
# 3    TCGA-AR-A1AJ    Negative  Negative  Positive    HR Positive
# 4    TCGA-E2-A15S    Negative  Negative  Positive    HR Positive
# ..            ...         ...       ...       ...            ...
# 577  TCGA-A2-A04N    Negative  Positive  Positive    HR Positive
# 578  TCGA-AR-A1AS    Negative  Positive  Positive    HR Positive
# 579  TCGA-C8-A1HL    Positive  Negative  Positive  HER2 Positive
# 580  TCGA-AN-A0FF    Negative  Positive  Positive    HR Positive
# 581  TCGA-E2-A1AZ    Negative  Negative  Negative           TNBC
#
#      MEAN[CANCER_NUCLEUS_AREA]_H & E  MEAN[CANCER_NUCLEUS_CIRCULARITY]_H & E  \
# 0                          34.365021                                0.788894
# 1                          39.071213                                0.784081
# 2                          38.241444                                0.810570
# 3                          37.569180                                0.756555
# 4                          37.934071                                0.813011
# ..                               ...                                     ...
# 577                        40.167149                                0.786355
# 578                        47.793850                                0.759587
# 579                        48.468864                                0.763141
# 580                        33.570347                                0.766258
# 581                        43.516521                                0.798199
#
#      MEAN[CANCER_NUCLEUS_ECCENTRICITY]_H & E  \
# 0                                   0.682284
# 1                                   0.686660
# 2                                   0.643006
# 3                                   0.742634
# 4                                   0.654944
# ..                                       ...
# 577                                 0.661289
# 578                                 0.734216
# 579                                 0.713281
# 580                                 0.702174
# 581                                 0.678485
#
#      MEAN[CANCER_NUCLEUS_MAJOR_AXIS_LENGTH]_H & E  \
# 0                                        8.251385
# 1                                        8.686616
# 2                                        8.426938
# 3                                        9.057047
# 4                                        8.453368
# ..                                            ...
# 577                                      8.731260
# 578                                     10.062342
# 579                                      9.954347
# 580                                      8.304225
# 581                                      9.184370
#
#      MEAN[CANCER_NUCLEUS_MEAN_LAB_CHANNEL_A]_H & E  ...  \
# 0                                         0.602840  ...
# 1                                         0.600544  ...
# 2                                         0.606436  ...
# 3                                         0.615502  ...
# 4                                         0.610344  ...
# ..                                             ...  ...
# 577                                       0.652192  ...
# 578                                       0.616858  ...
# 579                                       0.607404  ...
# 580                                       0.594162  ...
# 581                                       0.605873  ...
#
#      STD[LYMPHOCYTE_NUCLEUS_MEAN_LAB_CHANNEL_B]_H & E  \
# 0                                            0.007224
# 1                                            0.017781
# 2                                            0.008084
# 3                                            0.007268
# 4                                            0.007589
# ..                                                ...
# 577                                          0.006646
# 578                                          0.008048
# 579                                          0.013180
# 580                                          0.007930
# 581                                          0.007995
#
#      STD[LYMPHOCYTE_NUCLEUS_MINOR_AXIS_LENGTH]_H & E  \
# 0                                           0.801812
# 1                                           0.727386
# 2                                           0.759774
# 3                                           0.646987
# 4                                           0.618312
# ..                                               ...
# 577                                         0.706071
# 578                                         0.731268
# 579                                         0.781547
# 580                                         0.731670
# 581                                         0.687270
#
#      STD[LYMPHOCYTE_NUCLEUS_MIN_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.051126
# 1                                             0.057589
# 2                                             0.039343
# 3                                             0.033704
# 4                                             0.048938
# ..                                                 ...
# 577                                           0.044662
# 578                                           0.040083
# 579                                           0.060307
# 580                                           0.033249
# 581                                           0.053845
#
#      STD[LYMPHOCYTE_NUCLEUS_MIN_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.065717
# 1                                             0.072681
# 2                                             0.064644
# 3                                             0.076382
# 4                                             0.055562
# ..                                                 ...
# 577                                           0.079656
# 578                                           0.078726
# 579                                           0.072402
# 580                                           0.076339
# 581                                           0.055913
#
#      STD[LYMPHOCYTE_NUCLEUS_PERIMETER]_H & E  \
# 0                                   3.289017
# 1                                   3.023650
# 2                                   2.844278
# 3                                   2.803650
# 4                                   2.364664
# ..                                       ...
# 577                                 2.822683
# 578                                 3.091555
# 579                                 3.213238
# 580                                 3.251431
# 581                                 2.680880
#
#      STD[LYMPHOCYTE_NUCLEUS_SOLIDITY]_H & E  \
# 0                                  0.019602
# 1                                  0.019152
# 2                                  0.016114
# 3                                  0.020363
# 4                                  0.012161
# ..                                      ...
# 577                                0.016338
# 578                                0.018503
# 579                                0.018057
# 580                                0.021967
# 581                                0.015694
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_GRAYSCALE_CHANNEL_GRAY]_H & E  \
# 0                                             0.020905
# 1                                             0.021876
# 2                                             0.020894
# 3                                             0.021541
# 4                                             0.020599
# ..                                                 ...
# 577                                           0.021173
# 578                                           0.022948
# 579                                           0.022812
# 580                                           0.022200
# 581                                           0.020625
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_HSV_CHANNEL_SATURATION]_H & E  \
# 0                                             0.020543
# 1                                             0.021078
# 2                                             0.018527
# 3                                             0.025585
# 4                                             0.023713
# ..                                                 ...
# 577                                           0.020896
# 578                                           0.024541
# 579                                           0.023739
# 580                                           0.018067
# 581                                           0.021181
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_A]_H & E  \
# 0                                           0.003352
# 1                                           0.004379
# 2                                           0.004438
# 3                                           0.003586
# 4                                           0.003215
# ..                                               ...
# 577                                         0.004519
# 578                                         0.003706
# 579                                         0.004350
# 580                                         0.003412
# 581                                         0.003558
#
#      STD[LYMPHOCYTE_NUCLEUS_STD_LAB_CHANNEL_B]_H & E
# 0                                           0.004804
# 1                                           0.006619
# 2                                           0.006021
# 3                                           0.006296
# 4                                           0.005068
# ..                                               ...
# 577                                         0.003546
# 578                                         0.005923
# 579                                         0.006741
# 580                                         0.007163
# 581                                         0.005208
#
# [582 rows x 95 columns]

# %%
# Path for the output CSV file
tcga_brca_subtype_to_original_nuhifs = f"{outputs_path}tcga_brca_subtype_to_original_nuhifs.csv"

# Write the merged dataframe to a new CSV file
merged_df1.to_csv(tcga_brca_subtype_to_original_nuhifs, index=False)

print("The files have been mapped and saved to:", tcga_brca_subtype_to_original_nuhifs)
print("Done!")
# Out:
# The files have been mapped and saved to: PA_NUHIF_BRCA/outputs_biomarker_status/tcga_brca_subtype_to_original_nuhifs.csv
# Done!
