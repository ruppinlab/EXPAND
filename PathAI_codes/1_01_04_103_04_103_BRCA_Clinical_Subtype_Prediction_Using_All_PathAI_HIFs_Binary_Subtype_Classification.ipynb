# %%
#### ---------------------------------------------------------------------------------------------------------------------------
#### author: Ranjan Barman, date: July 11, 2025
#### predict individual BRCA Subtype Status using All HoverNet predicted NPIFs and also save the models for external validation
#### ----------------------------------------------------------------------------------------------------------------------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from collections import Counter, defaultdict
from sklearn.model_selection import cross_val_predict, StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score, f1_score, roc_auc_score, roc_curve, auc
import random
import joblib

_wpath_ = "/data/Lab_ruppin/Ranjan/HnE/"
os.chdir(_wpath_)

print(f"working directory = {_wpath_}\n")
# Out:
# working directory = /data/Lab_ruppin/Ranjan/HnE/

# %%
# Define dataset and file paths
dataset_name = "PA_HIF_BRCA"
outcome_names = ["HER2_Status", "PR_Status", "ER_Status"]

# File paths
PathAI_HIFs_with_BRCA_status_file = f"{dataset_name}/clinical_tcga_brca_outputs/tcga_brca_subtype_to_original_hifs.csv"

# Output path to save results and plots
out_path = f"{dataset_name}/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/"
model_save_path = os.path.join(out_path, "saved_models/")
os.makedirs(model_save_path, exist_ok=True) # Creates directory if it doesn't exist already

# read files 
PathAI_HIFs_with_BRCA_status_full = pd.read_csv(PathAI_HIFs_with_BRCA_status_file)

# Remove trailing spaces from column names
PathAI_HIFs_with_BRCA_status_full.columns = PathAI_HIFs_with_BRCA_status_full.columns.str.strip()


# The number of samples used for TCGA BRCA subtype prediction 
TCGA_BRCA_Subtypes_556_file = "TCGA_BRCA_FFPE/outputs/HoverNet/Subtypes/outputs_biomarker_status_prediction_results_All_HoverNet_NPIFs/combined_class_predictions_all_features_for_subtypes.csv"

TCGA_BRCA_Subtypes_556 = pd.read_csv(TCGA_BRCA_Subtypes_556_file)

# Convert the first column ("sample") to a series
sample_list_556 = TCGA_BRCA_Subtypes_556['sample_id'].reset_index(drop=True)

# Filter sample based on `sample_list_556`
PathAI_HIFs_with_BRCA_status_full = PathAI_HIFs_with_BRCA_status_full[PathAI_HIFs_with_BRCA_status_full['sample_id'].isin(sample_list_556)].copy()

# Convert the first column ("sample") to a series
patient_list = PathAI_HIFs_with_BRCA_status_full['sample_id'].reset_index(drop=True)

# Filter to include only rows where outcome is "Positive" or "Negative"
data_filtered = PathAI_HIFs_with_BRCA_status_full[
    PathAI_HIFs_with_BRCA_status_full[outcome_names].isin(["Positive", "Negative"]).all(axis=1)
]


# Filter out the patient list
filtered_patient_list = data_filtered['sample_id'].reset_index(drop=True)

# Define features (before normalization)
X = data_filtered.iloc[:, 4:].copy()


PathAI_HIFs_with_BRCA_status_full
filtered_patient_list
data_filtered
X
# Out:
#      AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE  \
# 0                                     5.884160
# 1                                     7.959952
# 2                                    10.708352
# 3                                     1.600576
# 4                                     6.305520
# ..                                         ...
# 718                                 103.655120
# 719                                  12.700832
# 720                                  87.381168
# 721                                  15.787328
# 722                                  31.392272
#
#      AREA (MM2) OF [ESI_0080] IN [TISSUE]_HE  \
# 0                                   8.505324
# 1                                  15.879072
# 2                                  20.749744
# 3                                  13.634196
# 4                                  14.302604
# ..                                       ...
# 718                                92.218780
# 719                                22.796892
# 720                               109.834856
# 721                                39.763816
# 722                                40.723992
#
#      AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE  \
# 0                                   1.389632
# 1                                   1.843632
# 2                                   0.011680
# 3                                   0.061824
# 4                                   0.235024
# ..                                       ...
# 718                                12.361056
# 719                                 0.269024
# 720                                 1.369792
# 721                                 0.046576
# 722                                 0.453456
#
#      AREA (MM2) OF [STROMA] IN [TISSUE]_HE  \
# 0                                12.406016
# 1                                18.089680
# 2                                17.366224
# 3                                31.309600
# 4                                13.158768
# ..                                     ...
# 718                              41.098096
# 719                              24.320192
# 720                              73.197504
# 721                              34.822016
# 722                              23.556064
#
#      AREA (MM2) OF [TUMOR] IN [TISSUE]_HE  \
# 0                               18.290176
# 1                               26.049632
# 2                               28.074576
# 3                               32.910176
# 4                               19.464288
# ..                                    ...
# 718                            144.753216
# 719                             37.021024
# 720                            160.578672
# 721                             50.609344
# 722                             54.948336
#
#      AREA PROP [[EPITHELIAL] OVER [TUMOR]] IN [TISSUE]_HE  \
# 0                                             0.321712
# 1                                             0.305569
# 2                                             0.381425
# 3                                             0.048635
# 4                                             0.323953
# ..                                                 ...
# 718                                           0.716082
# 719                                           0.343071
# 720                                           0.544164
# 721                                           0.311945
# 722                                           0.571305
#
#      AREA PROP [[ESI_0080] OVER [TUMOR]] IN [TISSUE]_HE  \
# 0                                             0.465021
# 1                                             0.609570
# 2                                             0.739094
# 3                                             0.414285
# 4                                             0.734813
# ..                                                 ...
# 718                                           0.637076
# 719                                           0.615782
# 720                                           0.683994
# 721                                           0.785701
# 722                                           0.741132
#
#      AREA PROP [[STROMA] OVER [TUMOR]] IN [TISSUE]_HE  \
# 0                                            0.678288
# 1                                            0.694431
# 2                                            0.618575
# 3                                            0.951365
# 4                                            0.676047
# ..                                                ...
# 718                                          0.283918
# 719                                          0.656929
# 720                                          0.455836
# 721                                          0.688055
# 722                                          0.428695
#
#      CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN EPITHELIAL_HE  \
# 0                                          5549.618334
# 1                                          5439.532405
# 2                                          6151.863384
# 3                                          4381.536397
# 4                                          5467.894943
# ..                                                 ...
# 718                                        6678.220676
# 719                                        4778.077157
# 720                                        6708.959338
# 721                                        5876.813984
# 722                                        6880.757794
#
#      CELL CLUSTERING PROPERTIES: BALL-HALL INDEX OF CANCER IN ESI_0080_HE  \
# 0                                          5114.173347
# 1                                          5490.280441
# 2                                          6541.817199
# 3                                          4017.597431
# 4                                          6185.684156
# ..                                                 ...
# 718                                        6830.624908
# 719                                        5766.431072
# 720                                        6758.871148
# 721                                        6811.574201
# 722                                        7226.370118
#
#      ...  TOTAL [LYMPHOCYTE CELLS] IN [STROMA]_HE  \
# 0    ...                                  19166.0
# 1    ...                                   8826.0
# 2    ...                                   2739.0
# 3    ...                                  37415.0
# 4    ...                                   5098.0
# ..   ...                                      ...
# 718  ...                                  97532.0
# 719  ...                                   7446.0
# 720  ...                                  32669.0
# 721  ...                                  37521.0
# 722  ...                                  13262.0
#
#      TOTAL [LYMPHOCYTE CELLS] IN [TUMOR]_HE  \
# 0                                   24610.0
# 1                                   10351.0
# 2                                    3675.0
# 3                                   39063.0
# 4                                    5776.0
# ..                                      ...
# 718                                167641.0
# 719                                  8802.0
# 720                                 42024.0
# 721                                 40134.0
# 722                                 17464.0
#
#      TOTAL [MACROPHAGE CELLS] IN [EPITHELIAL]_HE  \
# 0                                          706.0
# 1                                          999.0
# 2                                          146.0
# 3                                         1171.0
# 4                                          310.0
# ..                                           ...
# 718                                       4818.0
# 719                                        859.0
# 720                                       2351.0
# 721                                        946.0
# 722                                        993.0
#
#      TOTAL [MACROPHAGE CELLS] IN [ESI_0080]_HE  \
# 0                                       1362.0
# 1                                       1207.0
# 2                                        412.0
# 3                                       4474.0
# 4                                        442.0
# ..                                         ...
# 718                                    17008.0
# 719                                     1119.0
# 720                                     5264.0
# 721                                     3141.0
# 722                                     1449.0
#
#      TOTAL [MACROPHAGE CELLS] IN [STROMA]_HE  \
# 0                                     2353.0
# 1                                     2520.0
# 2                                      465.0
# 3                                     8911.0
# 4                                      936.0
# ..                                       ...
# 718                                  20185.0
# 719                                   3124.0
# 720                                   7560.0
# 721                                   6808.0
# 722                                   2289.0
#
#      TOTAL [MACROPHAGE CELLS] IN [TUMOR]_HE  \
# 0                                    3059.0
# 1                                    3519.0
# 2                                     611.0
# 3                                   10082.0
# 4                                    1246.0
# ..                                      ...
# 718                                 25003.0
# 719                                  3983.0
# 720                                  9911.0
# 721                                  7754.0
# 722                                  3282.0
#
#      TOTAL [PLASMA CELLS] IN [EPITHELIAL]_HE  \
# 0                                      825.0
# 1                                      311.0
# 2                                      144.0
# 3                                      252.0
# 4                                      207.0
# ..                                       ...
# 718                                   8546.0
# 719                                    215.0
# 720                                   3636.0
# 721                                    453.0
# 722                                    707.0
#
#      TOTAL [PLASMA CELLS] IN [ESI_0080]_HE  \
# 0                                    949.0
# 1                                    412.0
# 2                                    269.0
# 3                                   1546.0
# 4                                    389.0
# ..                                     ...
# 718                                14439.0
# 719                                  261.0
# 720                                 7865.0
# 721                                 1587.0
# 722                                  818.0
#
#      TOTAL [PLASMA CELLS] IN [STROMA]_HE  TOTAL [PLASMA CELLS] IN [TUMOR]_HE
# 0                                 1383.0                              2208.0
# 1                                  523.0                               834.0
# 2                                  260.0                               404.0
# 3                                 3023.0                              3275.0
# 4                                  427.0                               634.0
# ..                                   ...                                 ...
# 718                              10629.0                             19175.0
# 719                                526.0                               741.0
# 720                               7104.0                             10740.0
# 721                               2399.0                              2852.0
# 722                                769.0                              1476.0
#
# [556 rows x 607 columns]

# %%
# Initialize a DataFrame to store the combined results
combined_results_df = pd.DataFrame({'sample_id': filtered_patient_list.values})
combined_results_df.set_index('sample_id', inplace=True)

# Define hyperparameter grid for Logistic Regression with L2 penalty (Ridge)
param_grid = {
    'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
}

# Define cross-validation parameters
n_folds = 5
seed = 20852
shuffle = True

# Define subtype names
subtype_names_3 = ['HER2_Positive', 'HR_Positive', 'TNBC_3']
subtype_names_4 = ['HR+', 'TNBC_4', 'TPBC', 'HER2+']
all_subtype_names = subtype_names_3 + subtype_names_4

# Step 1: Define true subtypes from HER2/ER/PR status
def define_true_subtypes(df):
    HER2 = df['HER2_Status'] == 'Positive'
    ER = df['ER_Status'] == 'Positive'
    PR = df['PR_Status'] == 'Positive'

    df['HER2_Positive'] = HER2.astype(int)
    df['HR_Positive'] = ((ER | PR) & ~HER2).astype(int)
    df['TNBC_3'] = (~HER2 & ~ER & ~PR).astype(int)

    df['HR+'] = (ER & ~HER2).astype(int)
    df['TNBC_4'] = (~ER & ~HER2).astype(int)
    df['TPBC'] = (ER & HER2).astype(int)
    df['HER2+'] = (~ER & HER2).astype(int)

    return df

# Apply subtype definition
data_filtered = define_true_subtypes(data_filtered)

# Step 2: Define NPIF features only (exclude all label-related columns)
columns_to_exclude = ['sample_id', 'HER2_Status', 'PR_Status', 'ER_Status',
                      'HER2_Positive', 'HR_Positive', 'TNBC_3', 'HR+',
                      'TNBC_4', 'TPBC', 'HER2+']
feature_columns = [col for col in data_filtered.columns if col not in columns_to_exclude]
X = data_filtered[feature_columns].copy()

data_filtered
# feature_columns
# X
# Out:
#         sample_id HER2_Status PR_Status ER_Status  \
# 0    TCGA-A1-A0SB    Negative  Negative  Positive
# 1    TCGA-A1-A0SD    Negative  Positive  Positive
# 2    TCGA-A1-A0SE    Negative  Positive  Positive
# 3    TCGA-A1-A0SF    Negative  Positive  Positive
# 4    TCGA-A1-A0SH    Negative  Positive  Negative
# ..            ...         ...       ...       ...
# 718  TCGA-EW-A1PB    Negative  Negative  Negative
# 719  TCGA-EW-A1PD    Positive  Positive  Positive
# 720  TCGA-EW-A1PE    Negative  Positive  Positive
# 721  TCGA-EW-A1PF    Negative  Positive  Positive
# 722  TCGA-EW-A1PG    Negative  Positive  Positive
#
#      AREA (MM2) OF [EPITHELIAL] IN [TISSUE]_HE  \
# 0                                     5.884160
# 1                                     7.959952
# 2                                    10.708352
# 3                                     1.600576
# 4                                     6.305520
# ..                                         ...
# 718                                 103.655120
# 719                                  12.700832
# 720                                  87.381168
# 721                                  15.787328
# 722                                  31.392272
#
#      AREA (MM2) OF [ESI_0080] IN [TISSUE]_HE  \
# 0                                   8.505324
# 1                                  15.879072
# 2                                  20.749744
# 3                                  13.634196
# 4                                  14.302604
# ..                                       ...
# 718                                92.218780
# 719                                22.796892
# 720                               109.834856
# 721                                39.763816
# 722                                40.723992
#
#      AREA (MM2) OF [NECROSIS] IN [TISSUE]_HE  \
# 0                                   1.389632
# 1                                   1.843632
# 2                                   0.011680
# 3                                   0.061824
# 4                                   0.235024
# ..                                       ...
# 718                                12.361056
# 719                                 0.269024
# 720                                 1.369792
# 721                                 0.046576
# 722                                 0.453456
#
#      AREA (MM2) OF [STROMA] IN [TISSUE]_HE  \
# 0                                12.406016
# 1                                18.089680
# 2                                17.366224
# 3                                31.309600
# 4                                13.158768
# ..                                     ...
# 718                              41.098096
# 719                              24.320192
# 720                              73.197504
# 721                              34.822016
# 722                              23.556064
#
#      AREA (MM2) OF [TUMOR] IN [TISSUE]_HE  \
# 0                               18.290176
# 1                               26.049632
# 2                               28.074576
# 3                               32.910176
# 4                               19.464288
# ..                                    ...
# 718                            144.753216
# 719                             37.021024
# 720                            160.578672
# 721                             50.609344
# 722                             54.948336
#
#      AREA PROP [[EPITHELIAL] OVER [TUMOR]] IN [TISSUE]_HE  ...  \
# 0                                             0.321712     ...
# 1                                             0.305569     ...
# 2                                             0.381425     ...
# 3                                             0.048635     ...
# 4                                             0.323953     ...
# ..                                                 ...     ...
# 718                                           0.716082     ...
# 719                                           0.343071     ...
# 720                                           0.544164     ...
# 721                                           0.311945     ...
# 722                                           0.571305     ...
#
#      TOTAL [PLASMA CELLS] IN [ESI_0080]_HE  \
# 0                                    949.0
# 1                                    412.0
# 2                                    269.0
# 3                                   1546.0
# 4                                    389.0
# ..                                     ...
# 718                                14439.0
# 719                                  261.0
# 720                                 7865.0
# 721                                 1587.0
# 722                                  818.0
#
#      TOTAL [PLASMA CELLS] IN [STROMA]_HE  TOTAL [PLASMA CELLS] IN [TUMOR]_HE  \
# 0                                 1383.0                              2208.0
# 1                                  523.0                               834.0
# 2                                  260.0                               404.0
# 3                                 3023.0                              3275.0
# 4                                  427.0                               634.0
# ..                                   ...                                 ...
# 718                              10629.0                             19175.0
# 719                                526.0                               741.0
# 720                               7104.0                             10740.0
# 721                               2399.0                              2852.0
# 722                                769.0                              1476.0
#
#      HER2_Positive  HR_Positive  TNBC_3  HR+  TNBC_4  TPBC  HER2+
# 0                0            1       0    1       0     0      0
# 1                0            1       0    1       0     0      0
# 2                0            1       0    1       0     0      0
# 3                0            1       0    1       0     0      0
# 4                0            1       0    0       1     0      0
# ..             ...          ...     ...  ...     ...   ...    ...
# 718              0            0       1    0       1     0      0
# 719              1            0       0    0       0     1      0
# 720              0            1       0    1       0     0      0
# 721              0            1       0    1       0     0      0
# 722              0            1       0    1       0     0      0
#
# [556 rows x 618 columns]

# %%
# Initialize result storage
results = {}
mean_f1_scores = []

# Loop through each subtype
for subtype in all_subtype_names:
    print(f"\nProcessing subtype: {subtype}")
    
    y = data_filtered[subtype]
    y_encoded = y.copy()

    outer_results = []
    y_true_all_folds = []
    predictions = []
    f1_scores = []

    # Track coefficients for all features across folds
    all_features = X.columns.tolist()
    coeff_tracker = {feat: [] for feat in all_features}  # values per fold, zero if not selected

    outer_cv = StratifiedKFold(n_splits=n_folds, shuffle=shuffle, random_state=seed)
    fold_idx = 1

    for train_idx, test_idx in outer_cv.split(X, y_encoded):
        print(f"\nOuter Fold {fold_idx}/{n_folds}")
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y_encoded.iloc[train_idx], y_encoded.iloc[test_idx]
        patient_test_ids = filtered_patient_list.iloc[test_idx]

        # Print class balance
        print("Train class dist:", y_train.value_counts().to_dict())
        print("Test class dist :", y_test.value_counts().to_dict())

        inner_cv = StratifiedKFold(n_splits=n_folds, shuffle=shuffle, random_state=seed)
        
        pipeline = Pipeline([
            ('scaler', MinMaxScaler()),
            ('classifier', LogisticRegression(penalty='l1', solver='saga',
                                              class_weight='balanced', max_iter=10000))
        ])
        
        grid_search = GridSearchCV(
            estimator=pipeline,
            param_grid=param_grid,
            cv=inner_cv,
            scoring='roc_auc',
            n_jobs=-1
        )
        
        grid_search.fit(X_train, y_train)
        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
        print(f"Best parameters: {best_params}")
        
        # Save model
        model_filename = os.path.join(model_save_path, f"{subtype}_model_fold_{fold_idx}.joblib")
        joblib.dump(best_model, model_filename)
        print(f"Saved model with scaler: {model_filename}")

        # Extract coefficients
        coef = best_model.named_steps['classifier'].coef_.flatten()
        for feat, c in zip(all_features, coef):
            coeff_tracker[feat].append(c)  # may be zero

        # Predict
        y_pred_proba = best_model.predict_proba(X_test)[:, 1]
        predictions.append(y_pred_proba)
        y_true_all_folds.extend(y_test)

        # Save predictions to results DataFrame
        combined_results_df.loc[patient_test_ids.values, f'true_label_{subtype}'] = y_test.values
        combined_results_df.loc[patient_test_ids.values, f'predicted_probability_{subtype}'] = y_pred_proba

        # Evaluate
        f1 = f1_score(y_test, (y_pred_proba >= 0.5).astype(int))
        roc_auc = roc_auc_score(y_test, y_pred_proba)
        f1_scores.append(f1)

        print(f"F1-score: {f1:.4f}")
        print(f"ROC AUC : {roc_auc:.4f}")

        outer_results.append({
            'fold': fold_idx,
            'f1_score': f1,
            'roc_auc': roc_auc,
            'best_params': best_params
        })

        fold_idx += 1

    # Save results
    mean_f1_score = np.mean(f1_scores)
    print(f"Mean F1-score for {subtype}: {mean_f1_score:.4f}")

    results[subtype] = {
        'outer_results': outer_results,
        'mean_f1_score': mean_f1_score,
        'best_params': best_params
    }
    mean_f1_scores.append(mean_f1_score)

    # Fill missing folds with 0s
    for feat in coeff_tracker:
        if len(coeff_tracker[feat]) < n_folds:
            coeff_tracker[feat] += [0.0] * (n_folds - len(coeff_tracker[feat]))
    
    # Convert to DataFrame with fold-wise rows and features as columns
    fold_coefficients_df = pd.DataFrame(coeff_tracker)
    fold_coefficients_df.index.name = 'fold'
    fold_coefficients_df.index = [f'Fold_{i+1}' for i in range(n_folds)]
    
    # Save all coefficients (including zeros) fold-wise
    coeff_output_file = os.path.join(out_path, f"{subtype}_foldwise_coefficients.csv")
    fold_coefficients_df.to_csv(coeff_output_file)
    print(f"Saved fold-wise coefficients (including zeros) for {subtype} to: {coeff_output_file}")
# Out:
# Processing subtype: HER2_Positive
#
# Outer Fold 1/5
# Train class dist: {0: 378, 1: 66}
# Test class dist : {0: 95, 1: 17}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2_Positive_model_fold_1.joblib
# F1-score: 0.3462
# ROC AUC : 0.7554
#
# Outer Fold 2/5
# Train class dist: {0: 378, 1: 67}
# Test class dist : {0: 95, 1: 16}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2_Positive_model_fold_2.joblib
# F1-score: 0.3830
# ROC AUC : 0.7605
#
# Outer Fold 3/5
# Train class dist: {0: 378, 1: 67}
# Test class dist : {0: 95, 1: 16}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2_Positive_model_fold_3.joblib
# F1-score: 0.1905
# ROC AUC : 0.6125
#
# Outer Fold 4/5
# Train class dist: {0: 379, 1: 66}
# Test class dist : {0: 94, 1: 17}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2_Positive_model_fold_4.joblib
# F1-score: 0.2553
# ROC AUC : 0.6733
#
# Outer Fold 5/5
# Train class dist: {0: 379, 1: 66}
# Test class dist : {0: 94, 1: 17}
# Best parameters: {'classifier__C': 10}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2_Positive_model_fold_5.joblib
# F1-score: 0.3784
# ROC AUC : 0.7190
# Mean F1-score for HER2_Positive: 0.3107
# Saved fold-wise coefficients (including zeros) for HER2_Positive to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/HER2_Positive_foldwise_coefficients.csv
#
# Processing subtype: HR_Positive
#
# Outer Fold 1/5
# Train class dist: {1: 296, 0: 148}
# Test class dist : {1: 74, 0: 38}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR_Positive_model_fold_1.joblib
# F1-score: 0.7391
# ROC AUC : 0.7592
#
# Outer Fold 2/5
# Train class dist: {1: 296, 0: 149}
# Test class dist : {1: 74, 0: 37}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR_Positive_model_fold_2.joblib
# F1-score: 0.8201
# ROC AUC : 0.8499
#
# Outer Fold 3/5
# Train class dist: {1: 296, 0: 149}
# Test class dist : {1: 74, 0: 37}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR_Positive_model_fold_3.joblib
# F1-score: 0.8143
# ROC AUC : 0.8192
#
# Outer Fold 4/5
# Train class dist: {1: 296, 0: 149}
# Test class dist : {1: 74, 0: 37}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR_Positive_model_fold_4.joblib
# F1-score: 0.8649
# ROC AUC : 0.8671
#
# Outer Fold 5/5
# Train class dist: {1: 296, 0: 149}
# Test class dist : {1: 74, 0: 37}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR_Positive_model_fold_5.joblib
# F1-score: 0.8276
# ROC AUC : 0.8510
# Mean F1-score for HR_Positive: 0.8132
# Saved fold-wise coefficients (including zeros) for HR_Positive to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/HR_Positive_foldwise_coefficients.csv
#
# Processing subtype: TNBC_3
#
# Outer Fold 1/5
# Train class dist: {0: 362, 1: 82}
# Test class dist : {0: 91, 1: 21}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_3_model_fold_1.joblib
# F1-score: 0.4898
# ROC AUC : 0.8048
#
# Outer Fold 2/5
# Train class dist: {0: 362, 1: 83}
# Test class dist : {0: 91, 1: 20}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_3_model_fold_2.joblib
# F1-score: 0.5385
# ROC AUC : 0.8302
#
# Outer Fold 3/5
# Train class dist: {0: 362, 1: 83}
# Test class dist : {0: 91, 1: 20}
# Best parameters: {'classifier__C': 0.1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_3_model_fold_3.joblib
# F1-score: 0.6667
# ROC AUC : 0.8786
#
# Outer Fold 4/5
# Train class dist: {0: 363, 1: 82}
# Test class dist : {0: 90, 1: 21}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_3_model_fold_4.joblib
# F1-score: 0.5098
# ROC AUC : 0.7894
#
# Outer Fold 5/5
# Train class dist: {0: 363, 1: 82}
# Test class dist : {0: 90, 1: 21}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_3_model_fold_5.joblib
# F1-score: 0.6512
# ROC AUC : 0.8116
# Mean F1-score for TNBC_3: 0.5712
# Saved fold-wise coefficients (including zeros) for TNBC_3 to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/TNBC_3_foldwise_coefficients.csv
#
# Processing subtype: HR+
#
# Outer Fold 1/5
# Train class dist: {1: 288, 0: 156}
# Test class dist : {1: 73, 0: 39}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR+_model_fold_1.joblib
# F1-score: 0.8467
# ROC AUC : 0.8704
#
# Outer Fold 2/5
# Train class dist: {1: 289, 0: 156}
# Test class dist : {1: 72, 0: 39}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR+_model_fold_2.joblib
# F1-score: 0.8056
# ROC AUC : 0.8184
#
# Outer Fold 3/5
# Train class dist: {1: 289, 0: 156}
# Test class dist : {1: 72, 0: 39}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR+_model_fold_3.joblib
# F1-score: 0.7407
# ROC AUC : 0.7678
#
# Outer Fold 4/5
# Train class dist: {1: 289, 0: 156}
# Test class dist : {1: 72, 0: 39}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR+_model_fold_4.joblib
# F1-score: 0.8000
# ROC AUC : 0.8355
#
# Outer Fold 5/5
# Train class dist: {1: 289, 0: 156}
# Test class dist : {1: 72, 0: 39}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HR+_model_fold_5.joblib
# F1-score: 0.7914
# ROC AUC : 0.8130
# Mean F1-score for HR+: 0.7969
# Saved fold-wise coefficients (including zeros) for HR+ to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/HR+_foldwise_coefficients.csv
#
# Processing subtype: TNBC_4
#
# Outer Fold 1/5
# Train class dist: {0: 355, 1: 89}
# Test class dist : {0: 89, 1: 23}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_4_model_fold_1.joblib
# F1-score: 0.5246
# ROC AUC : 0.7763
#
# Outer Fold 2/5
# Train class dist: {0: 355, 1: 90}
# Test class dist : {0: 89, 1: 22}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_4_model_fold_2.joblib
# F1-score: 0.4815
# ROC AUC : 0.8151
#
# Outer Fold 3/5
# Train class dist: {0: 355, 1: 90}
# Test class dist : {0: 89, 1: 22}
# Best parameters: {'classifier__C': 0.1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_4_model_fold_3.joblib
# F1-score: 0.6071
# ROC AUC : 0.8442
#
# Outer Fold 4/5
# Train class dist: {0: 355, 1: 90}
# Test class dist : {0: 89, 1: 22}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_4_model_fold_4.joblib
# F1-score: 0.6087
# ROC AUC : 0.8381
#
# Outer Fold 5/5
# Train class dist: {0: 356, 1: 89}
# Test class dist : {0: 88, 1: 23}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TNBC_4_model_fold_5.joblib
# F1-score: 0.5965
# ROC AUC : 0.8335
# Mean F1-score for TNBC_4: 0.5637
# Saved fold-wise coefficients (including zeros) for TNBC_4 to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/TNBC_4_foldwise_coefficients.csv
#
# Processing subtype: TPBC
#
# Outer Fold 1/5
# Train class dist: {0: 398, 1: 46}
# Test class dist : {0: 100, 1: 12}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TPBC_model_fold_1.joblib
# F1-score: 0.1778
# ROC AUC : 0.5392
#
# Outer Fold 2/5
# Train class dist: {0: 398, 1: 47}
# Test class dist : {0: 100, 1: 11}
# Best parameters: {'classifier__C': 100}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TPBC_model_fold_2.joblib
# F1-score: 0.3333
# ROC AUC : 0.7245
#
# Outer Fold 3/5
# Train class dist: {0: 398, 1: 47}
# Test class dist : {0: 100, 1: 11}
# Best parameters: {'classifier__C': 10}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TPBC_model_fold_3.joblib
# F1-score: 0.2581
# ROC AUC : 0.6427
#
# Outer Fold 4/5
# Train class dist: {0: 399, 1: 46}
# Test class dist : {0: 99, 1: 12}
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TPBC_model_fold_4.joblib
# F1-score: 0.1250
# ROC AUC : 0.5859
#
# Outer Fold 5/5
# Train class dist: {0: 399, 1: 46}
# Test class dist : {0: 99, 1: 12}
# Best parameters: {'classifier__C': 100}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/TPBC_model_fold_5.joblib
# F1-score: 0.0667
# ROC AUC : 0.5202
# Mean F1-score for TPBC: 0.1922
# Saved fold-wise coefficients (including zeros) for TPBC to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/TPBC_foldwise_coefficients.csv
#
# Processing subtype: HER2+
#
# Outer Fold 1/5
# Train class dist: {0: 424, 1: 20}
# Test class dist : {0: 107, 1: 5}
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2+_model_fold_1.joblib
# F1-score: 0.4286
# ROC AUC : 0.7701
#
# Outer Fold 2/5
# Train class dist: {0: 425, 1: 20}
# Test class dist : {0: 106, 1: 5}
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'classifier__C': 0.1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2+_model_fold_2.joblib
# F1-score: 0.1379
# ROC AUC : 0.7189
#
# Outer Fold 3/5
# Train class dist: {0: 425, 1: 20}
# Test class dist : {0: 106, 1: 5}
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'classifier__C': 0.1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2+_model_fold_3.joblib
# F1-score: 0.2051
# ROC AUC : 0.8208
#
# Outer Fold 4/5
# Train class dist: {0: 425, 1: 20}
# Test class dist : {0: 106, 1: 5}
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'classifier__C': 1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2+_model_fold_4.joblib
# F1-score: 0.2143
# ROC AUC : 0.8453
#
# Outer Fold 5/5
# Train class dist: {0: 425, 1: 20}
# Test class dist : {0: 106, 1: 5}
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/Anaconda/envs/py3.10/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'classifier__C': 0.1}
# Saved model with scaler: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/saved_models/HER2+_model_fold_5.joblib
# F1-score: 0.3226
# ROC AUC : 0.9151
# Mean F1-score for HER2+: 0.2617
# Saved fold-wise coefficients (including zeros) for HER2+ to: PA_HIF_BRCA/outputs/Prediction_results_PathAI_HIFs_Binary_Subtypes/HER2+_foldwise_coefficients.csv

# %%
# Save combined prediction outputs
combined_results_df.to_csv(os.path.join(out_path, 'combined_class_predictions_all_subtypes_binary.csv'), index=True)
combined_results_df
# Out:
#               true_label_HER2_Positive  predicted_probability_HER2_Positive  \
# sample_id
# TCGA-A1-A0SB                       0.0                             0.117025
# TCGA-A1-A0SD                       0.0                             0.201354
# TCGA-A1-A0SE                       0.0                             0.103531
# TCGA-A1-A0SF                       0.0                             0.012240
# TCGA-A1-A0SH                       0.0                             0.335964
# ...                                ...                                  ...
# TCGA-EW-A1PB                       0.0                             0.018109
# TCGA-EW-A1PD                       1.0                             0.034059
# TCGA-EW-A1PE                       0.0                             0.240083
# TCGA-EW-A1PF                       0.0                             0.298471
# TCGA-EW-A1PG                       0.0                             0.399443
#
#               true_label_HR_Positive  predicted_probability_HR_Positive  \
# sample_id
# TCGA-A1-A0SB                     1.0                           0.732718
# TCGA-A1-A0SD                     1.0                           0.695725
# TCGA-A1-A0SE                     1.0                           0.930385
# TCGA-A1-A0SF                     1.0                           0.620354
# TCGA-A1-A0SH                     1.0                           0.739211
# ...                              ...                                ...
# TCGA-EW-A1PB                     0.0                           0.178462
# TCGA-EW-A1PD                     0.0                           0.774162
# TCGA-EW-A1PE                     1.0                           0.466554
# TCGA-EW-A1PF                     1.0                           0.727899
# TCGA-EW-A1PG                     1.0                           0.655351
#
#               true_label_TNBC_3  predicted_probability_TNBC_3  true_label_HR+  \
# sample_id
# TCGA-A1-A0SB                0.0                      0.511169             1.0
# TCGA-A1-A0SD                0.0                      0.213142             1.0
# TCGA-A1-A0SE                0.0                      0.047368             1.0
# TCGA-A1-A0SF                0.0                      0.313540             1.0
# TCGA-A1-A0SH                0.0                      0.107856             0.0
# ...                         ...                           ...             ...
# TCGA-EW-A1PB                1.0                      0.701393             0.0
# TCGA-EW-A1PD                0.0                      0.267007             0.0
# TCGA-EW-A1PE                0.0                      0.491174             1.0
# TCGA-EW-A1PF                0.0                      0.298807             1.0
# TCGA-EW-A1PG                0.0                      0.114431             1.0
#
#               predicted_probability_HR+  true_label_TNBC_4  \
# sample_id
# TCGA-A1-A0SB                   0.512474                0.0
# TCGA-A1-A0SD                   0.620048                0.0
# TCGA-A1-A0SE                   0.934451                0.0
# TCGA-A1-A0SF                   0.314582                0.0
# TCGA-A1-A0SH                   0.714930                1.0
# ...                                 ...                ...
# TCGA-EW-A1PB                   0.090310                1.0
# TCGA-EW-A1PD                   0.761715                0.0
# TCGA-EW-A1PE                   0.407739                0.0
# TCGA-EW-A1PF                   0.813069                0.0
# TCGA-EW-A1PG                   0.718692                0.0
#
#               predicted_probability_TNBC_4  true_label_TPBC  \
# sample_id
# TCGA-A1-A0SB                      0.793364              0.0
# TCGA-A1-A0SD                      0.359102              0.0
# TCGA-A1-A0SE                      0.072023              0.0
# TCGA-A1-A0SF                      0.224410              0.0
# TCGA-A1-A0SH                      0.198816              0.0
# ...                                    ...              ...
# TCGA-EW-A1PB                      0.695855              0.0
# TCGA-EW-A1PD                      0.263110              1.0
# TCGA-EW-A1PE                      0.501606              0.0
# TCGA-EW-A1PF                      0.303146              0.0
# TCGA-EW-A1PG                      0.118480              0.0
#
#               predicted_probability_TPBC  true_label_HER2+  \
# sample_id
# TCGA-A1-A0SB                7.875122e-03               0.0
# TCGA-A1-A0SD                3.645992e-05               0.0
# TCGA-A1-A0SE                2.813547e-06               0.0
# TCGA-A1-A0SF                2.381951e-01               0.0
# TCGA-A1-A0SH                3.442538e-05               0.0
# ...                                  ...               ...
# TCGA-EW-A1PB                6.167321e-08               0.0
# TCGA-EW-A1PD                1.726123e-01               0.0
# TCGA-EW-A1PE                2.773466e-01               0.0
# TCGA-EW-A1PF                1.028095e-03               0.0
# TCGA-EW-A1PG                1.767140e-01               0.0
#
#               predicted_probability_HER2+
# sample_id
# TCGA-A1-A0SB                     0.156488
# TCGA-A1-A0SD                     0.449947
# TCGA-A1-A0SE                     0.000007
# TCGA-A1-A0SF                     0.700800
# TCGA-A1-A0SH                     0.310712
# ...                                   ...
# TCGA-EW-A1PB                     0.472818
# TCGA-EW-A1PD                     0.000026
# TCGA-EW-A1PE                     0.510609
# TCGA-EW-A1PF                     0.017221
# TCGA-EW-A1PG                     0.318099
#
# [556 rows x 14 columns]

# %%
# Mapping for 3-subtype ROC plotting
subtypes_3 = {
    'HER2_Positive': ('true_label_HER2_Positive', 'predicted_probability_HER2_Positive'),
    'HR_Positive': ('true_label_HR_Positive', 'predicted_probability_HR_Positive'),
    'TNBC_3': ('true_label_TNBC_3', 'predicted_probability_TNBC_3')
}

# Mapping for 4-subtype ROC plotting
subtypes_4 = {
    'HR+': ('true_label_HR+', 'predicted_probability_HR+'),
    'TNBC_4': ('true_label_TNBC_4', 'predicted_probability_TNBC_4'),
    'TPBC': ('true_label_TPBC', 'predicted_probability_TPBC'),
    'HER2+': ('true_label_HER2+', 'predicted_probability_HER2+')
}

# %%
colors = {
    'HER2_Positive': 'darkorange',
    'HR_Positive': 'blue',
    'TNBC_3': 'green',
    'HR+': 'blue',
    'TNBC_4': 'green',
    'TPBC': 'tomato',
    'HER2+': 'darkorange'
}
def plot_combined_roc_curves(df, subtypes, title, filename):
    plt.figure(figsize=(10, 8))
    total_samples = len(df)

    for subtype, (true_label_col, pred_prob_col) in subtypes.items():
        if subtype in ['TNBC_3', 'TNBC_4']:
            if 'TNBC' in colors:  # Avoid duplicated legend for TNBC
                continue
            label = 'TNBC'
        elif subtype == 'HER2_Positive':
            label = 'HER2+'
        elif subtype == 'HR_Positive':
            label = 'HR+'
        else:
            label = subtype

        # Filter valid entries
        valid_indices = (~df[true_label_col].isna()) & (~df[pred_prob_col].isna())
        true_labels = df[true_label_col][valid_indices]
        predicted_probs = df[pred_prob_col][valid_indices]

        # Compute ROC and AUC
        fpr, tpr, _ = roc_curve(true_labels, predicted_probs)
        roc_auc = auc(fpr, tpr)

        # Plot
        plt.plot(fpr, tpr, color=colors[subtype], lw=2,
                 label=f'{label} (AUC = {roc_auc:.2f}, n = {true_labels.sum():.0f})')

    # Reference diagonal
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontsize=18)
    plt.ylabel('True Positive Rate', fontsize=18)
    plt.title(title, fontsize=18)
    plt.legend(loc="lower right", fontsize=18)
    plt.grid(True)

    # Save and show
    plt.savefig(os.path.join(out_path, filename), bbox_inches='tight')
    plt.show()

# %%
plot_combined_roc_curves(
    combined_results_df,
    subtypes_3,
    'ROC Curves for BRCA 3 Clinical Subtypes',
    'roc_3_subtypes.png'
)

plot_combined_roc_curves(
    combined_results_df,
    subtypes_4,
    'ROC Curves for BRCA 4 Clinical Subtypes',
    'roc_4_subtypes.png'
)
